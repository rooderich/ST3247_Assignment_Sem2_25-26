# %% [markdown]
# # ST3247 Final Assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import stats

from simulator import simulate

# %%
# Load the observed data
infected_df  = pd.read_csv("data/infected_timeseries.csv")
rewire_df  = pd.read_csv("data/rewiring_timeseries.csv")
degree_df  = pd.read_csv("data/final_degree_histograms.csv")

# Pivot such that rows = time steps, columns = replicates
inf_wide = infected_df.pivot(index="time", columns="replicate_id", values="infected_fraction")
rew_wide = rewire_df.pivot(index="time", columns="replicate_id", values="rewire_count")

N_REPS = inf_wide.shape[1]
T = inf_wide.shape[0] - 1   # 200 time steps (0..200)
print(f"Replicates: {N_REPS}   Time steps: {T}")
# Out:
# Replicates: 40   Time steps: 200

# %% [markdown]
# ## 0. Data and Inference Problem
#
# We observe data from 40 independent realisations of a stochastic SIR epidemic
# on an adaptive network, all generated with the same unknown parameter vector
# (β, γ, ρ). Three aggregate measurements are available per replicate: the
# infected fraction time series, the rewiring count time series, and the final
# degree histogram.
#
# The likelihood function p(data | β, γ, ρ) is intractable because the contact
# network evolves stochastically and is never observed. Marginalising over all
# possible network trajectories is computationally infeasible. We therefore use
# Simulation-Based Inference (SBI), specifically rejection ABC, which bypasses
# likelihood evaluation entirely by comparing summary statistics of simulated
# and observed data.

# %% [markdown]
# ## 1. Defining the candidate statistics summary

# %% [markdown]
# ### 1.1 Infection time-series features
#
# (mainly informative about β and γ)
# - Peak height: max(infected_fraction)
# - Time to peak: argmax(infected_fraction)
# - Area under the curve: sum(infected_fraction)
# - Epidemic duration: last time step where infected_fraction > 0.01
# - Growth rate: slope of the log-infected curve in the first ~ 5 steps

# %%
peak_height = inf_wide.max(axis=0)
time_to_peak = inf_wide.idxmax(axis=0)
auc = inf_wide.sum(axis=0) # area under the curve (sum of infected fractions over time)
duration = (inf_wide > 0).sum(axis=0) # number of time steps with non-zero infections

# growth rate
def growth_rate(col):
    """
    Estimate the initial exponential growth rate of the epidemic from the time-series data.
    We take the first 7 time steps (t=1..7) to avoid the initial stochasticity at t=0 and the later saturation effects.
    We fit a line to the log of the infected fraction over these time steps, and return the slope as the growth rate.
    We also replace any zero or negative values with a small positive number (1e-6) to avoid issues with taking the log.
    """
    early = col.iloc[1:8].values   # t=1..7
    early = np.where(early <= 0, 1e-6, early)
    return np.polyfit(np.arange(len(early)), np.log(early), 1)[0]

growth = inf_wide.apply(growth_rate, axis=0)

features_inf = pd.DataFrame({
    "peak_height": peak_height,
    "time_to_peak": time_to_peak,
    "auc": auc,
    "duration": duration,
    "growth_rate": growth
})

print("\nPer-replicate infection summary statistics:")
print(features_inf.describe().round(4))

print("\nCoefficient of Variation (std/mean) — lower = tighter = better summary stat:")
cv = (features_inf.std() / features_inf.mean()).round(4)
print(cv.to_string())
# Out:
# Per-replicate infection summary statistics:
#        peak_height  time_to_peak      auc  duration  growth_rate
# count      40.0000       40.0000  40.0000   40.0000      40.0000
# mean        0.6571        8.7500  11.3990   75.8000       0.3752
# std         0.0427        1.1929   0.8785   16.1534       0.0384
# min         0.5400        7.0000   9.9050   52.0000       0.2878
# 25%         0.6338        8.0000  10.5962   63.5000       0.3478
# 50%         0.6625        8.5000  11.4825   72.0000       0.3771
# 75%         0.6812        9.0000  12.0263   87.0000       0.3959
# max         0.7700       12.0000  13.7200  116.0000       0.4588
#
# Coefficient of Variation (std/mean) — lower = tighter = better summary stat:
# peak_height     0.0649
# time_to_peak    0.1363
# auc             0.0771
# duration        0.2131
# growth_rate     0.1022

# %% [markdown]
# Interpretation of infection summaries:
# - peak_height and auc are very stable and hence good candidate summary statistics for the infection time series data.
# - growth_rate is informative and reasonably stable.
# - time_to_peak is moderately variable, hence must be used carefully.
# - duration is quite noisy, hence less reliable as a summary statistic.

# %% [markdown]
# ### 1.2 Rewiring time series features
#
# (mainly informative about ρ)
# - Total rewires: sum(rewire_counts)
# - Peak rewire count and time of peak
# - Rewire-weighted time: center of mass of rewiring activity to determine if rewiring happens early or late
# - Ratio of max rewires to peak infection: a ρ/β interaction

# %%
total_rewires  = rew_wide.sum(axis=0)
peak_rewires   = rew_wide.max(axis=0)
time_peak_rew  = rew_wide.idxmax(axis=0)

# centre of mass of rewiring activity - when rewiring happens early, this will be low; when it happens late, this will be high
times = np.arange(T+1)
rew_centre_of_mass = rew_wide.apply(
    lambda col: np.average(times, weights = np.maximum(col.values, 0))
    if col.sum() > 0 else np.nan,  # if there are no rewires, we set the centre of mass to NaN to avoid division by zero
    axis = 0
)

# rewiring to infection ratio at the time of peak infection - this captures the interaction between β and ρ
rew_inf_ratio = peak_rewires / (peak_height * 200) # rewires per infected agent

features_rew = pd.DataFrame({
    "total_rewires": total_rewires,
    "peak_rewires": peak_rewires,
    "time_peak_rew": time_peak_rew,
    "rew_centre_of_mass": rew_centre_of_mass,
    "rew_inf_ratio": rew_inf_ratio
})

print("\nPer-replicate rewiring summary statistics:")
print(features_rew.describe().round(4))

print("\nCoefficient of Variation (std/mean) — lower = tighter = better summary stat:")
cv_rew = (features_rew.std() / features_rew.mean()).round(4)
print(cv_rew.to_string())
# Out:
# Per-replicate rewiring summary statistics:
#        total_rewires  peak_rewires  time_peak_rew  rew_centre_of_mass  \
# count        40.0000       40.0000         40.000             40.0000
# mean        545.1500       98.1250          5.500              5.2440
# std          38.6248       10.2111          1.281              0.7852
# min         441.0000       79.0000          4.000              3.5193
# 25%         520.2500       91.7500          5.000              4.7349
# 50%         547.0000       97.0000          5.000              5.2056
# 75%         579.7500      104.5000          6.000              5.7838
# max         608.0000      118.0000          9.000              7.3684
#
#        rew_inf_ratio
# count        40.0000
# mean          0.7476
# std           0.0720
# min           0.5940
# 25%           0.6950
# 50%           0.7462
# 75%           0.8000
# max           0.8981
#
# Coefficient of Variation (std/mean) — lower = tighter = better summary stat:
# total_rewires         0.0709
# peak_rewires          0.1041
# time_peak_rew         0.2329
# rew_centre_of_mass    0.1497
# rew_inf_ratio         0.0963

# %% [markdown]
# Interpretation:
# - total_rewires is a strong summary statistic.
# - rew_inf_ratio and peak_rewires are also good summary statistics.
# - rew_centre_of_mass is moderately variable, hence must be used carefully.
# - time_peak_rew is noisy, hence less reliable as a summary statistic.

# %% [markdown]
# ### 1.3 Final degree histogram features
# - Mean final degree: should be ≈10 regardless of parameters (edge count conserved)
# - Variance of final degree
# - Gini Coefficient
# - Fraction of nodes with degree <= 5 (low-degree tail)
# - Fraction of nodes with degree >=15 (high degree tail)

# %%
def degree_stats(grp):
    """
    Calculate summary statistics of the degree distribution for a single replicate.
    The input grp is a DataFrame containing the degree histogram for one replicate, with columns "degree" and "count".
    We compute the mean degree, variance of degree, Gini coefficient (a measure of inequality in the degree distribution), and the fractions of nodes in the low-degree tail (degree <= 5) and high-degree tail (degree >= 15). 
    The Gini coefficient should decrease as ρ increases, since higher rewiring should homogenize the degree distribution. 
    The low-degree tail should increase with ρ, while the high-degree tail should decrease with ρ, since rewiring tends to break up hubs and create more low-degree nodes. 
    """
    degrees = grp["degree"].values
    counts = grp["count"].values
    total = counts.sum()
    mean_deg = np.average(degrees, weights=counts)
    var_deg = np.average((degrees - mean_deg)**2, weights=counts)
    
    # Gini coefficient - measures inequality of degree distribution: Higher rho should homogenize the degrees and lead to a lower Gini coefficient
    sorted_deg = np.repeat(degrees, counts)
    n = len(sorted_deg)
    gini = (2 * np.sum((np.arange(1, n+1) * sorted_deg)) / (n * np.sum(sorted_deg))) - (n + 1) / n
    # Low-degree tail: fraction of nodes with degree <= 5
    low_tail = np.sum(counts[degrees <= 5]) / total
    # High-degree tail: fraction of nodes with degree >= 15
    high_tail = np.sum(counts[degrees >= 15]) / total
    return pd.Series({
        "mean_degree": mean_deg,
        "var_degree": var_deg,
        "gini_degree": gini,
        "low_degree_tail": low_tail,
        "high_degree_tail": high_tail
    })
    

features_deg = degree_df.groupby("replicate_id").apply(degree_stats)

print("\nPer-replicate degree distribution summary statistics:")
print(features_deg.describe().round(4))

print("\nCoefficient of Variation (std/mean) — lower = tighter = better summary stat:")
cv_deg = (features_deg.std() / features_deg.mean()).round(4)
print(cv_deg.to_string())
# Out:
# Per-replicate degree distribution summary statistics:
#        mean_degree  var_degree  gini_degree  low_degree_tail  high_degree_tail
# count      40.0000     40.0000      40.0000          40.0000           40.0000
# mean       10.0172     10.3410       0.1797           0.0694            0.0906
# std         0.3209      1.2410       0.0107           0.0212            0.0280
# min         9.2900      8.0675       0.1585           0.0350            0.0450
# 25%         9.8450      9.4413       0.1721           0.0538            0.0688
# 50%        10.0000     10.1318       0.1807           0.0675            0.0900
# 75%        10.2575     11.2307       0.1891           0.0812            0.1112
# max        10.5900     13.1396       0.2022           0.1350            0.1450
#
# Coefficient of Variation (std/mean) — lower = tighter = better summary stat:
# mean_degree         0.0320
# var_degree          0.1200
# gini_degree         0.0597
# low_degree_tail     0.3059
# high_degree_tail    0.3091
# /var/folders/z9/41w961mj1jnffsfx31fd6z5m0000gn/T/ipykernel_76341/203549863.py:32: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   features_deg = degree_df.groupby("replicate_id").apply(degree_stats)

# %% [markdown]
# Interpretation of degree summaries:
# - mean_degree is stable but uninformative as it always remains around 10.
# - gini_degree is a reliable summary statistic.
# - var =_degree is moderately stable as a summary statistic, hence must be used carefully.
# - low_degree_tail and high_degree_tail are very noisy, hence not reliable as summary statistics.

# %% [markdown]
# ### Conclusion based on CV
#
# Yes:
# - mean_degree (degree) - uninformative
# - peak_height (infection)
# - gini_degree (degree)
# - auc (infection)
# - total_rewires (rewire)
# - rew_inf__ratio (rewire)
# - peak_rewires (rewire)
# - growth_rate (infection)
#
# Consider:
# - var_degree (degree)
# - time_to_peak (infection)
# - rew_centre_of_mass (rewire)

# %% [markdown]
# ### 1.4 Cross Source Correlations
#
# Checking for redundancy between candidate statistics.

# %%
all_features = pd.concat([features_inf, features_rew, features_deg], axis=1)
corr = all_features.corr().round(3)
print("\nFull correlation matrix:")
print(corr.to_string())
# Out:
# Full correlation matrix:
#                     peak_height  time_to_peak    auc  duration  growth_rate  total_rewires  peak_rewires  time_peak_rew  rew_centre_of_mass  rew_inf_ratio  mean_degree  var_degree  gini_degree  low_degree_tail  high_degree_tail
# peak_height               1.000        -0.387  0.515    -0.007        0.463         -0.454         0.440         -0.355              -0.470         -0.212        0.254      -0.134       -0.281           -0.009             0.001
# time_to_peak             -0.387         1.000  0.115     0.273       -0.350          0.645        -0.494          0.772               0.840         -0.274       -0.357       0.150        0.396            0.394             0.009
# auc                       0.515         0.115  1.000     0.324        0.351          0.052         0.005          0.064               0.051         -0.352        0.005       0.061        0.038            0.196            -0.085
# duration                 -0.007         0.273  0.324     1.000        0.137          0.276        -0.000          0.311               0.362          0.023       -0.065      -0.027       -0.026           -0.041            -0.070
# growth_rate               0.463        -0.350  0.351     0.137        1.000         -0.223         0.378         -0.220              -0.216          0.098        0.120      -0.082       -0.150            0.154            -0.090
# total_rewires            -0.454         0.645  0.052     0.276       -0.223          1.000        -0.301          0.614               0.716         -0.016        0.071       0.288        0.291            0.165             0.284
# peak_rewires              0.440        -0.494  0.005    -0.000        0.378         -0.301         1.000         -0.275              -0.433          0.782        0.296      -0.233       -0.412           -0.264             0.032
# time_peak_rew            -0.355         0.772  0.064     0.311       -0.220          0.614        -0.275          1.000               0.869         -0.046       -0.226       0.365        0.517            0.394             0.191
# rew_centre_of_mass       -0.470         0.840  0.051     0.362       -0.216          0.716        -0.433          0.869               1.000         -0.141       -0.275       0.246        0.428            0.278             0.107
# rew_inf_ratio            -0.212        -0.274 -0.352     0.023        0.098         -0.016         0.782         -0.046              -0.141          1.000        0.143      -0.162       -0.254           -0.278             0.033
# mean_degree               0.254        -0.357  0.005    -0.065        0.120          0.071         0.296         -0.226              -0.275          0.143        1.000       0.375       -0.166           -0.518             0.701
# var_degree               -0.134         0.150  0.061    -0.027       -0.082          0.288        -0.233          0.365               0.246         -0.162        0.375       1.000        0.838            0.177             0.750
# gini_degree              -0.281         0.396  0.038    -0.026       -0.150          0.291        -0.412          0.517               0.428         -0.254       -0.166       0.838        1.000            0.524             0.428
# low_degree_tail          -0.009         0.394  0.196    -0.041        0.154          0.165        -0.264          0.394               0.278         -0.278       -0.518       0.177        0.524            1.000            -0.156
# high_degree_tail          0.001         0.009 -0.085    -0.070       -0.090          0.284         0.032          0.191               0.107          0.033        0.701       0.750        0.428           -0.156             1.000

# %% [markdown]
# ### Staged redundancy analysis
#
# We read the correlation matrix in two stages to identify which candidate
# statistics carry redundant information.
#
# **Stage 1 — Within-source redundancy:** For each source group (infection,
# rewiring, degree), we check all pairs among the CV survivors. Any pair
# exceeding |r| = 0.70 is considered redundant — we keep the one with lower
# CV or stronger theoretical motivation and drop the other.
#
# **Stage 2 — Cross-source redundancy:** After within-source pruning, we check
# all pairs across source groups among the surviving statistics. If no cross-source
# pair exceeds |r| = 0.70, the three sources carry non-overlapping information
# and all are justified in the final summary vector.

# %%
# Analyze the correlation matrix in groups

# Within infection features
print("\nCorrelation matrix: Infection features")
print(corr.loc[features_inf.columns, features_inf.columns].to_string())
# Out:
# Correlation matrix: Infection features
#               peak_height  time_to_peak    auc  duration  growth_rate
# peak_height         1.000        -0.387  0.515    -0.007        0.463
# time_to_peak       -0.387         1.000  0.115     0.273       -0.350
# auc                 0.515         0.115  1.000     0.324        0.351
# duration           -0.007         0.273  0.324     1.000        0.137
# growth_rate         0.463        -0.350  0.351     0.137        1.000

# %% [markdown]
# - None exceed 0.70.
# - peak_height, auc, growth_rate are moderately correlated with each other (r ≈ 0.35–0.52). They are not redundant but they are not independent either.

# %%
# Within rewiring features
print("\nCorrelation matrix: Rewiring features")
print(corr.loc[features_rew.columns, features_rew.columns].to_string())
# Out:
# Correlation matrix: Rewiring features
#                     total_rewires  peak_rewires  time_peak_rew  rew_centre_of_mass  rew_inf_ratio
# total_rewires               1.000        -0.301          0.614               0.716         -0.016
# peak_rewires               -0.301         1.000         -0.275              -0.433          0.782
# time_peak_rew               0.614        -0.275          1.000               0.869         -0.046
# rew_centre_of_mass          0.716        -0.433          0.869               1.000         -0.141
# rew_inf_ratio              -0.016         0.782         -0.046              -0.141          1.000

# %% [markdown]
# - peak_rewires and rew_inf_ratio are a redundant pair (r = 0.782) => rew_inf_ratio normalized by epidemic size which is theoretically more meaningful.
# - total_rewires and rew_centre_of_mass also a redundant pair (r = 0.716) => total_rewires have a lower CV.

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))

rewiring_redundant_pairs = [
    (peak_rewires,  rew_inf_ratio,
    "Peak rewires",  "Rewires / infected agent",
    "r = +0.782  (|r| > 0.70)\n"
    "Drop peak_rewires — rew_inf_ratio is more theoretically\n"
    "motivated (normalises by epidemic size)"),
    (total_rewires, rew_centre_of_mass,
    "Total rewires", "Rewiring centre of mass",
    "r = +0.716  (|r| > 0.70)\n"
    "Drop rew_centre_of_mass — total_rewires has lower CV\n"
    "(0.071 vs 0.150)"),
]

for ax, (x, y, xl, yl, note) in zip(axes, rewiring_redundant_pairs):
    r, p = stats.pearsonr(x, y)
    ax.scatter(x, y, color="#0F6E56", alpha=0.7,
            edgecolors="white", linewidth=0.5, s=55)
    m, b = np.polyfit(x, y, 1)
    xr = np.linspace(x.min(), x.max(), 100)
    ax.plot(xr, m*xr + b, color="#085041", linewidth=1.5, alpha=0.6)
    ax.set_xlabel(xl, fontsize=10)
    ax.set_ylabel(yl, fontsize=10)
    ax.set_title(note, fontsize=9)

plt.suptitle(
    "Figure 1 — Within-rewiring redundancy: two pairs exceed |r| = 0.70\n"
    "Evidence for dropping peak_rewires and rew_centre_of_mass",
    fontsize=10
)
plt.tight_layout()
plt.show()

# %%
# Within degree features
print("\nCorrelation matrix: Degree features")
print(corr.loc[features_deg.columns, features_deg.columns].to_string())
# Out:
# Correlation matrix: Degree features
#                   mean_degree  var_degree  gini_degree  low_degree_tail  high_degree_tail
# mean_degree             1.000       0.375       -0.166           -0.518             0.701
# var_degree              0.375       1.000        0.838            0.177             0.750
# gini_degree            -0.166       0.838        1.000            0.524             0.428
# low_degree_tail        -0.518       0.177        0.524            1.000            -0.156
# high_degree_tail        0.701       0.750        0.428           -0.156             1.000

# %% [markdown]
# - var_degree and gini_degree are highly correlated and hence redundant pair (r = 0.838) => var_degree more interpretable.

# %%
fig, ax = plt.subplots(figsize=(5.5, 4.5))

var_degree = features_deg["var_degree"]
gini_degree = features_deg["gini_degree"]

r, p = stats.pearsonr(var_degree, gini_degree)
ax.scatter(var_degree, gini_degree, color="#D85A30", alpha=0.7,
        edgecolors="white", linewidth=0.5, s=55)
m, b = np.polyfit(var_degree, gini_degree, 1)
xr = np.linspace(var_degree.min(), var_degree.max(), 100)
ax.plot(xr, m*xr + b, color="#993C1D", linewidth=1.5, alpha=0.6)
ax.set_xlabel("Degree variance", fontsize=10)
ax.set_ylabel("Gini coefficient of degree distribution", fontsize=10)
ax.set_title(
    f"r = {r:+.3f}  (|r| > 0.70)\n"
    "Both measure spread of the degree distribution\n"
    "Keeping var_degree (more interpretable); dropping gini_degree",
    fontsize=9
)

plt.suptitle(
    "Figure 2 — Within-degree redundancy: gini and variance exceed |r| = 0.70\n"
    "Evidence for dropping gini_degree",
    fontsize=10
)
plt.tight_layout()

# %%
# Cross source correlations of the interested pairs of features

# After analyzing CV and correlation matrices, the surviving candidates for summary statistics are:
# infection: peak_height, auc, growth_rate, time_to_peak
# rewiring: rew_inf_ratio, total_rewires
# degree: var_degree

print("\nCross-source correlations of selected features:")
selected_pairs = [
    ("peak_height", "rew_inf_ratio"),
    ("peak_height", "total_rewires"),
    ("peak_height", "var_degree"),
    ("auc", "rew_inf_ratio"),
    ("auc", "total_rewires"),
    ("auc", "var_degree"),
    ("growth_rate", "rew_inf_ratio"),
    ("growth_rate", "total_rewires"),
    ("growth_rate", "var_degree"),
    ("time_to_peak", "rew_inf_ratio"),
    ("time_to_peak", "total_rewires"),
    ("time_to_peak", "var_degree")
]
for feat_inf, feat_rew in selected_pairs:
    r = corr.loc[feat_inf, feat_rew]
    print(f"{feat_inf} vs {feat_rew}: r = {r:.3f}")
# Out:
# Cross-source correlations of selected features:
# peak_height vs rew_inf_ratio: r = -0.212
# peak_height vs total_rewires: r = -0.454
# peak_height vs var_degree: r = -0.134
# auc vs rew_inf_ratio: r = -0.352
# auc vs total_rewires: r = 0.052
# auc vs var_degree: r = 0.061
# growth_rate vs rew_inf_ratio: r = 0.098
# growth_rate vs total_rewires: r = -0.223
# growth_rate vs var_degree: r = -0.082
# time_to_peak vs rew_inf_ratio: r = -0.274
# time_to_peak vs total_rewires: r = 0.645
# time_to_peak vs var_degree: r = 0.150

# %% [markdown]
# - None of the cross source pairs exceed 0.70.

# %%
inf_names = ["peak_height", "auc", "growth_rate", "time_to_peak"]
rew_names = ["total_rewires", "rew_inf_ratio"]
deg_names = ["var_degree"]

row_names = inf_names + rew_names   # 6 rows
col_names = rew_names + deg_names   # 3 columns

mat  = np.zeros((len(row_names), len(col_names)))
pmat = np.zeros((len(row_names), len(col_names)))

for i, row in enumerate(row_names):
    for j, col in enumerate(col_names):
        if row == col:
            mat[i, j]  = 1.0
            pmat[i, j] = 0.0
        else:
            r, p = stats.pearsonr(all_features[row], all_features[col])
            mat[i, j]  = r
            pmat[i, j] = p

fig, ax = plt.subplots(figsize=(6.5, 7))

im = ax.imshow(mat, cmap="RdBu_r", vmin=-1, vmax=1, aspect="auto")
cbar = plt.colorbar(im, ax=ax, fraction=0.03, pad=0.04)
cbar.set_label("Pearson r", fontsize=9)

ax.set_xticks(range(len(col_names)))
ax.set_xticklabels(col_names, rotation=25, ha="right", fontsize=9)
ax.set_yticks(range(len(row_names)))
ax.set_yticklabels(row_names, fontsize=9)

for i in range(len(row_names)):
    for j in range(len(col_names)):
        star = "*" if pmat[i, j] < 0.05 else ""
        text_color = "white" if abs(mat[i, j]) > 0.55 else "black"
        ax.text(j, i, f"{mat[i,j]:+.2f}{star}",
                ha="center", va="center", fontsize=9,
                color=text_color)

ax.axhline(3.5, color="black", linewidth=1.5, linestyle="--", alpha=0.4)
ax.axvline(1.5, color="black", linewidth=1.5, linestyle="--", alpha=0.4)

ax.annotate("Infection rows", xy=(-0.25, 1.5), xycoords=("axes fraction", "data"),
            fontsize=8, style="italic", ha="right", va="center", rotation=90)
ax.annotate("Rewiring rows", xy=(-0.25, 4.5), xycoords=("axes fraction", "data"),
            fontsize=8, style="italic", ha="right", va="center", rotation=90)
ax.annotate("Rewiring cols", xy=(0.5, -0.12), xycoords=("data", "axes fraction"),
            fontsize=8, style="italic", ha="center", va="top")
ax.annotate("Degree col", xy=(2.0, -0.12), xycoords=("data", "axes fraction"),
            fontsize=8, style="italic", ha="center", va="top")

ax.set_title(
    "Cross-source correlations among all 7 survivors\n"
    "* = p < 0.05.  No pair exceeds |r| = 0.70\n"
    "→ all three data sources are non-redundant",
    fontsize=9, pad=14
)

plt.tight_layout()
plt.show()

# %%
# Final Summary of the selected statistics for ABC, with their observed means, observed stds (as minimum tolerances), and CVs.
final_stats = {
    "peak_height":   (peak_height.mean(),   peak_height.std(),   0.065),
    "auc":           (auc.mean(),            auc.std(),           0.077),
    "growth_rate":   (growth.mean(),         growth.std(),        0.102),
    "time_to_peak":  (time_to_peak.mean(),   time_to_peak.std(),  0.136),
    "total_rewires": (total_rewires.mean(),  total_rewires.std(), 0.071),
    "rew_inf_ratio": (rew_inf_ratio.mean(),  rew_inf_ratio.std(), 0.096),
    "var_degree":    (features_deg["var_degree"].mean(),
                    features_deg["var_degree"].std(), 0.120),
}

print(f"\n{'Statistic':<18} {'Obs. mean':>12} {'Obs. std (=ε floor)':>20} {'CV':>8}")
print("-" * 62)
for name, (mean, std, cv) in final_stats.items():
    print(f"  {name:<16} {mean:>12.4f} {std:>20.4f} {cv:>8.3f}")
# Out:
# Statistic             Obs. mean  Obs. std (=ε floor)       CV
# --------------------------------------------------------------
#   peak_height            0.6571               0.0427    0.065
#   auc                   11.3990               0.8785    0.077
#   growth_rate            0.3752               0.0384    0.102
#   time_to_peak           8.7500               1.1929    0.136
#   total_rewires        545.1500              38.6248    0.071
#   rew_inf_ratio          0.7476               0.0720    0.096
#   var_degree            10.3410               1.2410    0.120

# %% [markdown]
# The observed means above are the target values s_obs that ABC compares
# simulated data against. The observed standard deviations give a lower bound
# on the ABC tolerance ε — any tolerance smaller than the observed std would
# ask simulations to match the data more precisely than the data itself is
# reproducible across replicates, which is impossible by construction.

# %% [markdown]
# ## 2. Pilot Simulations

# %%
# ── Compute_summary_stats ───

def compute_summary_stats(inf_wide, rew_wide, deg_df):
    """
    Compute the 7-statistic summary vector used for ABC.

    Statistics chosen after CV filtering and within/cross-source correlation analysis:
    Infection : peak_height, auc, growth_rate, time_to_peak
    Rewiring  : total_rewires, rew_inf_ratio
    Degree    : var_degree

    rew_inf_ratio = mean(peak_rewire_count_per_rep) / (mean_peak_infected_fraction * 200)
    This normalises rewiring intensity by epidemic size, capturing the rho/beta interaction.
    Verified comparable between observed and simulated data: s_obs sits at the 36th percentile
    of the prior-predictive distribution (confirmed in pilot analysis).
    """
    # Infection
    peak_height  = inf_wide.max(axis=0).mean()
    time_to_peak = inf_wide.idxmax(axis=0).mean()
    auc          = inf_wide.sum(axis=0).mean()

    def _growth(col):
        early = col.iloc[1:8].values
        early = np.where(early <= 0, 1e-6, early)
        return np.polyfit(np.arange(len(early)), np.log(early), 1)[0]

    growth_rate = inf_wide.apply(_growth, axis=0).mean()

    # Rewiring
    total_rewires = rew_wide.sum(axis=0).mean()
    peak_rewires  = rew_wide.max(axis=0).mean()
    rew_inf_ratio = peak_rewires / (peak_height * 200)
    

    # Degree
    def _var_degree(grp):
        degrees = grp["degree"].values
        counts  = grp["count"].values
        mean_d  = np.average(degrees, weights=counts)
        return np.average((degrees - mean_d)**2, weights=counts)

    var_degree = deg_df.groupby(
        "replicate_id", group_keys=False
    ).apply(lambda g: pd.Series({"v": _var_degree(g)}), include_groups=False)["v"].mean()

    return {
        "peak_height":   peak_height,
        "auc":           auc,
        "growth_rate":   growth_rate,
        "time_to_peak":  time_to_peak,
        "total_rewires": total_rewires,
        "rew_inf_ratio": rew_inf_ratio,
        "var_degree":    var_degree,
    }


# Compute s_obs 
s_obs = compute_summary_stats(inf_wide, rew_wide, degree_df)

print("Observed summary statistics (s_obs):")
for k, v in s_obs.items():
    print(f"  {k:<18}: {v:.5f}")
# Out:
# Observed summary statistics (s_obs):
#   peak_height       : 0.65712
#   auc               : 11.39900
#   growth_rate       : 0.37520
#   time_to_peak      : 8.75000
#   total_rewires     : 545.15000
#   rew_inf_ratio     : 0.74662
#   var_degree        : 10.34102

# %%
# Prior definition
PRIOR = {
    "beta":  (0.05, 0.50),
    "gamma": (0.02, 0.20),
    "rho":   (0.00, 0.80),
}

def sample_prior(rng):
    beta  = rng.uniform(*PRIOR["beta"])
    gamma = rng.uniform(*PRIOR["gamma"])
    rho   = rng.uniform(*PRIOR["rho"])
    return beta, gamma, rho

# %%
REPS_PER_DRAW = 5

def simulate_summary(beta, gamma, rho, n_reps, rng):
    """
    Run n_reps simulations at (beta, gamma, rho) and return the
    averaged 6-statistic summary vector.
    """
    inf_cols = {}
    rew_cols = {}
    deg_rows = []

    for rep in range(n_reps):
        inf_frac, rew_counts, deg_hist = simulate(
            beta=beta, gamma=gamma, rho=rho, rng=rng
        )
        inf_cols[rep] = inf_frac
        rew_cols[rep] = rew_counts
        for d, c in enumerate(deg_hist):
            deg_rows.append({"replicate_id": rep, "degree": d, "count": int(c)})

    inf_w = pd.DataFrame(inf_cols)
    rew_w = pd.DataFrame(rew_cols)
    deg_d = pd.DataFrame(deg_rows)

    return compute_summary_stats(inf_w, rew_w, deg_d)

# %%
# Distance Function 

STAT_NAMES = list(s_obs.keys())
# ['peak_height', 'auc', 'growth_rate', 'time_to_peak',
#  'total_rewires', 'rew_inf_ratio', 'var_degree']

def normalized_distance(s_sim, s_obs_dict, sigma):
    """
    Normalized Euclidean distance between two summary vectors.

    Each component (s_sim[k] - s_obs[k]) is divided by sigma[k],
    the prior-predictive standard deviation of statistic k.
    This ensures all 7 statistics contribute equally to the distance
    regardless of their original scale.

    Parameters
    ----------
    s_sim     : dict,  simulated summary statistics
    s_obs_dict: dict,  observed summary statistics (s_obs)
    sigma     : dict,  normalizing constants (prior-predictive std per statistic)
    """
    d_sq = 0.0
    for k in STAT_NAMES:
        if sigma[k] > 0:
            d_sq += ((s_sim[k] - s_obs_dict[k]) / sigma[k]) ** 2
    return np.sqrt(d_sq)

# %%
# ── Pilot run ────────────────────────────────────────────────────
import time, os

N_PILOT     = 500
SAVE_EVERY  = 50
OUTPUT_FILE = "pilot_results.csv"

rng = np.random.default_rng(42)

# Delete the old pilot CSV first (if there is one)
if os.path.exists(OUTPUT_FILE):
    os.remove(OUTPUT_FILE)
    print(f"Deleted previous Output file")

results = []
print(f"Starting fresh pilot: {N_PILOT} draws, {REPS_PER_DRAW} reps each\n")

t_start = time.time()

for i in range(N_PILOT):
    beta, gamma, rho = sample_prior(rng)
    s_sim = simulate_summary(beta, gamma, rho, REPS_PER_DRAW, rng)

    row = {"beta": beta, "gamma": gamma, "rho": rho}
    row.update({f"s_{k}": v for k, v in s_sim.items()})
    results.append(row)

    elapsed = time.time() - t_start
    done    = i + 1
    rate    = done / elapsed
    eta_min = (N_PILOT - done) / rate / 60 if rate > 0 else 0

    print(f"  [{done:4d}/{N_PILOT}]  β={beta:.3f} γ={gamma:.3f} ρ={rho:.3f}"
        f"  | peak={s_sim['peak_height']:.3f}"
        f"  rewires={s_sim['total_rewires']:.0f}"
        f"  rew_inf_ratio={s_sim['rew_inf_ratio']:.3f}"
        f"  | ETA: {eta_min:.0f} min", flush=True)

    if done % SAVE_EVERY == 0 or done == N_PILOT:
        pd.DataFrame(results).to_csv(OUTPUT_FILE, index=False)
        print(f"  >> Saved {done} results to {OUTPUT_FILE}")

print(f"\nPilot complete. Total time: {(time.time()-t_start)/60:.1f} min")
# Out:
# Deleted previous Output file
# Starting fresh pilot: 500 draws, 5 reps each
#
#   [   1/500]  β=0.398 γ=0.099 ρ=0.687  | peak=0.722  rewires=780  rew_inf_ratio=1.475  | ETA: 1 min
#   [   2/500]  β=0.464 γ=0.162 ρ=0.559  | peak=0.629  rewires=498  rew_inf_ratio=1.366  | ETA: 1 min
#   [   3/500]  β=0.230 γ=0.063 ρ=0.012  | peak=0.781  rewires=13  rew_inf_ratio=0.038  | ETA: 1 min
#   [   4/500]  β=0.416 γ=0.124 ρ=0.209  | peak=0.710  rewires=160  rew_inf_ratio=0.494  | ETA: 1 min
#   [   5/500]  β=0.474 γ=0.085 ρ=0.625  | peak=0.767  rewires=604  rew_inf_ratio=1.348  | ETA: 1 min
#   [   6/500]  β=0.054 γ=0.189 ρ=0.773  | peak=0.034  rewires=63  rew_inf_ratio=7.059  | ETA: 1 min
#   [   7/500]  β=0.112 γ=0.190 ρ=0.192  | peak=0.270  rewires=370  rew_inf_ratio=0.748  | ETA: 1 min
#   [   8/500]  β=0.472 γ=0.170 ρ=0.071  | peak=0.656  rewires=44  rew_inf_ratio=0.172  | ETA: 1 min
#   [   9/500]  β=0.420 γ=0.141 ρ=0.399  | peak=0.677  rewires=331  rew_inf_ratio=0.922  | ETA: 1 min
#   [  10/500]  β=0.053 γ=0.037 ρ=0.105  | peak=0.666  rewires=445  rew_inf_ratio=0.294  | ETA: 1 min
#   [  11/500]  β=0.493 γ=0.182 ρ=0.717  | peak=0.515  rewires=719  rew_inf_ratio=1.726  | ETA: 1 min
#   [  12/500]  β=0.399 γ=0.073 ρ=0.712  | peak=0.785  rewires=838  rew_inf_ratio=1.424  | ETA: 1 min
#   [  13/500]  β=0.361 γ=0.133 ρ=0.223  | peak=0.686  rewires=178  rew_inf_ratio=0.513  | ETA: 1 min
#   [  14/500]  β=0.453 γ=0.107 ρ=0.455  | peak=0.736  rewires=411  rew_inf_ratio=1.082  | ETA: 1 min
#   [  15/500]  β=0.327 γ=0.033 ρ=0.139  | peak=0.907  rewires=130  rew_inf_ratio=0.308  | ETA: 1 min
#   [  16/500]  β=0.197 γ=0.113 ρ=0.407  | peak=0.577  rewires=638  rew_inf_ratio=1.016  | ETA: 1 min
#   [  17/500]  β=0.386 γ=0.056 ρ=0.493  | peak=0.853  rewires=493  rew_inf_ratio=1.103  | ETA: 1 min
#   [  18/500]  β=0.447 γ=0.079 ρ=0.665  | peak=0.798  rewires=634  rew_inf_ratio=1.426  | ETA: 1 min
#   [  19/500]  β=0.440 γ=0.074 ρ=0.692  | peak=0.787  rewires=748  rew_inf_ratio=1.395  | ETA: 1 min
#   [  20/500]  β=0.465 γ=0.196 ρ=0.646  | peak=0.474  rewires=639  rew_inf_ratio=1.738  | ETA: 1 min
#   [  21/500]  β=0.090 γ=0.167 ρ=0.250  | peak=0.222  rewires=539  rew_inf_ratio=1.014  | ETA: 1 min
#   [  22/500]  β=0.065 γ=0.107 ρ=0.274  | peak=0.186  rewires=767  rew_inf_ratio=1.124  | ETA: 1 min
#   [  23/500]  β=0.432 γ=0.058 ρ=0.267  | peak=0.837  rewires=215  rew_inf_ratio=0.591  | ETA: 1 min
#   [  24/500]  β=0.460 γ=0.172 ρ=0.225  | peak=0.640  rewires=159  rew_inf_ratio=0.536  | ETA: 1 min
#   [  25/500]  β=0.387 γ=0.080 ρ=0.156  | peak=0.789  rewires=139  rew_inf_ratio=0.406  | ETA: 1 min
#   [  26/500]  β=0.497 γ=0.101 ρ=0.343  | peak=0.765  rewires=257  rew_inf_ratio=0.821  | ETA: 1 min
#   [  27/500]  β=0.334 γ=0.193 ρ=0.452  | peak=0.500  rewires=472  rew_inf_ratio=1.232  | ETA: 1 min
#   [  28/500]  β=0.225 γ=0.049 ρ=0.055  | peak=0.841  rewires=65  rew_inf_ratio=0.137  | ETA: 1 min
#   [  29/500]  β=0.322 γ=0.023 ρ=0.746  | peak=0.909  rewires=1052  rew_inf_ratio=1.479  | ETA: 1 min
#   [  30/500]  β=0.204 γ=0.095 ρ=0.256  | peak=0.663  rewires=364  rew_inf_ratio=0.650  | ETA: 1 min
#   [  31/500]  β=0.333 γ=0.053 ρ=0.297  | peak=0.857  rewires=295  rew_inf_ratio=0.650  | ETA: 1 min
#   [  32/500]  β=0.308 γ=0.102 ρ=0.009  | peak=0.744  rewires=10  rew_inf_ratio=0.028  | ETA: 1 min
#   [  33/500]  β=0.383 γ=0.176 ρ=0.584  | peak=0.557  rewires=601  rew_inf_ratio=1.451  | ETA: 1 min
#   [  34/500]  β=0.494 γ=0.020 ρ=0.620  | peak=0.947  rewires=594  rew_inf_ratio=1.281  | ETA: 1 min
#   [  35/500]  β=0.161 γ=0.131 ρ=0.153  | peak=0.561  rewires=238  rew_inf_ratio=0.453  | ETA: 1 min
#   [  36/500]  β=0.270 γ=0.020 ρ=0.567  | peak=0.921  rewires=778  rew_inf_ratio=1.114  | ETA: 1 min
#   [  37/500]  β=0.363 γ=0.194 ρ=0.246  | peak=0.579  rewires=201  rew_inf_ratio=0.632  | ETA: 1 min
#   [  38/500]  β=0.236 γ=0.069 ρ=0.529  | peak=0.743  rewires=778  rew_inf_ratio=1.194  | ETA: 1 min
#   [  39/500]  β=0.163 γ=0.173 ρ=0.571  | peak=0.136  rewires=553  rew_inf_ratio=2.485  | ETA: 1 min
#   [  40/500]  β=0.469 γ=0.055 ρ=0.188  | peak=0.881  rewires=133  rew_inf_ratio=0.404  | ETA: 1 min
#   [  41/500]  β=0.093 γ=0.155 ρ=0.134  | peak=0.327  rewires=296  rew_inf_ratio=0.563  | ETA: 1 min
#   [  42/500]  β=0.279 γ=0.105 ρ=0.259  | peak=0.699  rewires=275  rew_inf_ratio=0.585  | ETA: 1 min
#   [  43/500]  β=0.321 γ=0.107 ρ=0.493  | peak=0.694  rewires=559  rew_inf_ratio=1.072  | ETA: 1 min
#   [  44/500]  β=0.304 γ=0.116 ρ=0.729  | peak=0.599  rewires=1045  rew_inf_ratio=1.604  | ETA: 1 min
#   [  45/500]  β=0.206 γ=0.164 ρ=0.797  | peak=0.106  rewires=351  rew_inf_ratio=4.689  | ETA: 1 min
#   [  46/500]  β=0.152 γ=0.152 ρ=0.235  | peak=0.451  rewires=409  rew_inf_ratio=0.761  | ETA: 1 min
#   [  47/500]  β=0.474 γ=0.036 ρ=0.396  | peak=0.900  rewires=337  rew_inf_ratio=0.837  | ETA: 1 min
#   [  48/500]  β=0.170 γ=0.112 ρ=0.081  | peak=0.616  rewires=113  rew_inf_ratio=0.213  | ETA: 1 min
#   [  49/500]  β=0.152 γ=0.157 ρ=0.289  | peak=0.418  rewires=477  rew_inf_ratio=0.797  | ETA: 1 min
#   [  50/500]  β=0.355 γ=0.187 ρ=0.042  | peak=0.590  rewires=31  rew_inf_ratio=0.108  | ETA: 1 min
#   >> Saved 50 results to pilot_results.csv
#   [  51/500]  β=0.441 γ=0.058 ρ=0.798  | peak=0.828  rewires=928  rew_inf_ratio=1.527  | ETA: 1 min
#   [  52/500]  β=0.470 γ=0.131 ρ=0.078  | peak=0.716  rewires=57  rew_inf_ratio=0.184  | ETA: 1 min
#   [  53/500]  β=0.456 γ=0.095 ρ=0.243  | peak=0.790  rewires=191  rew_inf_ratio=0.568  | ETA: 1 min
#   [  54/500]  β=0.110 γ=0.106 ρ=0.515  | peak=0.182  rewires=652  rew_inf_ratio=1.709  | ETA: 1 min
#   [  55/500]  β=0.098 γ=0.085 ρ=0.014  | peak=0.571  rewires=32  rew_inf_ratio=0.056  | ETA: 1 min
#   [  56/500]  β=0.169 γ=0.159 ρ=0.592  | peak=0.224  rewires=881  rew_inf_ratio=1.879  | ETA: 1 min
#   [  57/500]  β=0.096 γ=0.169 ρ=0.761  | peak=0.041  rewires=80  rew_inf_ratio=6.024  | ETA: 1 min
#   [  58/500]  β=0.069 γ=0.143 ρ=0.428  | peak=0.054  rewires=152  rew_inf_ratio=2.648  | ETA: 1 min
#   [  59/500]  β=0.309 γ=0.166 ρ=0.368  | peak=0.563  rewires=380  rew_inf_ratio=0.947  | ETA: 1 min
#   [  60/500]  β=0.159 γ=0.092 ρ=0.799  | peak=0.075  rewires=178  rew_inf_ratio=5.387  | ETA: 1 min
#   [  61/500]  β=0.379 γ=0.177 ρ=0.562  | peak=0.537  rewires=567  rew_inf_ratio=1.326  | ETA: 1 min
#   [  62/500]  β=0.150 γ=0.073 ρ=0.333  | peak=0.666  rewires=643  rew_inf_ratio=0.829  | ETA: 1 min
#   [  63/500]  β=0.278 γ=0.135 ρ=0.525  | peak=0.589  rewires=656  rew_inf_ratio=1.306  | ETA: 1 min
#   [  64/500]  β=0.368 γ=0.084 ρ=0.710  | peak=0.732  rewires=864  rew_inf_ratio=1.526  | ETA: 1 min
#   [  65/500]  β=0.500 γ=0.167 ρ=0.351  | peak=0.664  rewires=271  rew_inf_ratio=0.938  | ETA: 1 min
#   [  66/500]  β=0.058 γ=0.041 ρ=0.263  | peak=0.579  rewires=1090  rew_inf_ratio=0.596  | ETA: 1 min
#   [  67/500]  β=0.354 γ=0.034 ρ=0.067  | peak=0.890  rewires=60  rew_inf_ratio=0.146  | ETA: 1 min
#   [  68/500]  β=0.365 γ=0.191 ρ=0.570  | peak=0.490  rewires=600  rew_inf_ratio=1.594  | ETA: 1 min
#   [  69/500]  β=0.499 γ=0.193 ρ=0.491  | peak=0.591  rewires=375  rew_inf_ratio=1.269  | ETA: 1 min
#   [  70/500]  β=0.205 γ=0.060 ρ=0.759  | peak=0.342  rewires=664  rew_inf_ratio=2.096  | ETA: 1 min
#   [  71/500]  β=0.300 γ=0.085 ρ=0.548  | peak=0.727  rewires=655  rew_inf_ratio=1.238  | ETA: 1 min
#   [  72/500]  β=0.321 γ=0.079 ρ=0.339  | peak=0.781  rewires=356  rew_inf_ratio=0.766  | ETA: 1 min
#   [  73/500]  β=0.446 γ=0.084 ρ=0.728  | peak=0.760  rewires=763  rew_inf_ratio=1.562  | ETA: 1 min
#   [  74/500]  β=0.303 γ=0.165 ρ=0.738  | peak=0.440  rewires=1066  rew_inf_ratio=1.852  | ETA: 1 min
#   [  75/500]  β=0.263 γ=0.127 ρ=0.617  | peak=0.566  rewires=848  rew_inf_ratio=1.440  | ETA: 1 min
#   [  76/500]  β=0.343 γ=0.081 ρ=0.783  | peak=0.716  rewires=1035  rew_inf_ratio=1.573  | ETA: 1 min
#   [  77/500]  β=0.360 γ=0.090 ρ=0.657  | peak=0.755  rewires=767  rew_inf_ratio=1.436  | ETA: 1 min
#   [  78/500]  β=0.055 γ=0.120 ρ=0.347  | peak=0.063  rewires=150  rew_inf_ratio=1.873  | ETA: 1 min
#   [  79/500]  β=0.215 γ=0.198 ρ=0.573  | peak=0.237  rewires=733  rew_inf_ratio=1.966  | ETA: 1 min
#   [  80/500]  β=0.092 γ=0.037 ρ=0.467  | peak=0.543  rewires=1201  rew_inf_ratio=0.952  | ETA: 1 min
#   [  81/500]  β=0.438 γ=0.163 ρ=0.610  | peak=0.597  rewires=599  rew_inf_ratio=1.635  | ETA: 1 min
#   [  82/500]  β=0.412 γ=0.100 ρ=0.507  | peak=0.728  rewires=483  rew_inf_ratio=1.216  | ETA: 1 min
#   [  83/500]  β=0.446 γ=0.119 ρ=0.780  | peak=0.671  rewires=855  rew_inf_ratio=1.662  | ETA: 1 min
#   [  84/500]  β=0.108 γ=0.133 ρ=0.461  | peak=0.119  rewires=506  rew_inf_ratio=2.059  | ETA: 1 min
#   [  85/500]  β=0.446 γ=0.057 ρ=0.540  | peak=0.847  rewires=533  rew_inf_ratio=1.210  | ETA: 1 min
#   [  86/500]  β=0.264 γ=0.046 ρ=0.483  | peak=0.840  rewires=666  rew_inf_ratio=1.037  | ETA: 1 min
#   [  87/500]  β=0.348 γ=0.025 ρ=0.505  | peak=0.900  rewires=552  rew_inf_ratio=1.072  | ETA: 1 min
#   [  88/500]  β=0.163 γ=0.142 ρ=0.318  | peak=0.493  rewires=540  rew_inf_ratio=0.836  | ETA: 1 min
#   [  89/500]  β=0.124 γ=0.082 ρ=0.161  | peak=0.595  rewires=325  rew_inf_ratio=0.418  | ETA: 1 min
#   [  90/500]  β=0.307 γ=0.194 ρ=0.204  | peak=0.526  rewires=196  rew_inf_ratio=0.635  | ETA: 1 min
#   [  91/500]  β=0.369 γ=0.061 ρ=0.641  | peak=0.820  rewires=726  rew_inf_ratio=1.394  | ETA: 1 min
#   [  92/500]  β=0.213 γ=0.034 ρ=0.400  | peak=0.872  rewires=571  rew_inf_ratio=0.849  | ETA: 1 min
#   [  93/500]  β=0.360 γ=0.179 ρ=0.146  | peak=0.591  rewires=116  rew_inf_ratio=0.372  | ETA: 1 min
#   [  94/500]  β=0.393 γ=0.071 ρ=0.791  | peak=0.746  rewires=986  rew_inf_ratio=1.527  | ETA: 1 min
#   [  95/500]  β=0.190 γ=0.039 ρ=0.026  | peak=0.829  rewires=39  rew_inf_ratio=0.075  | ETA: 1 min
#   [  96/500]  β=0.239 γ=0.070 ρ=0.379  | peak=0.765  rewires=496  rew_inf_ratio=0.875  | ETA: 1 min
#   [  97/500]  β=0.326 γ=0.121 ρ=0.496  | peak=0.649  rewires=520  rew_inf_ratio=1.176  | ETA: 1 min
#   [  98/500]  β=0.152 γ=0.058 ρ=0.473  | peak=0.748  rewires=962  rew_inf_ratio=1.055  | ETA: 1 min
#   [  99/500]  β=0.450 γ=0.081 ρ=0.170  | peak=0.820  rewires=140  rew_inf_ratio=0.399  | ETA: 1 min
#   [ 100/500]  β=0.347 γ=0.085 ρ=0.317  | peak=0.770  rewires=328  rew_inf_ratio=0.781  | ETA: 1 min
#   >> Saved 100 results to pilot_results.csv
#   [ 101/500]  β=0.173 γ=0.176 ρ=0.690  | peak=0.096  rewires=416  rew_inf_ratio=3.688  | ETA: 1 min
#   [ 102/500]  β=0.384 γ=0.082 ρ=0.702  | peak=0.761  rewires=815  rew_inf_ratio=1.615  | ETA: 1 min
#   [ 103/500]  β=0.459 γ=0.148 ρ=0.580  | peak=0.615  rewires=512  rew_inf_ratio=1.315  | ETA: 1 min
#   [ 104/500]  β=0.422 γ=0.083 ρ=0.708  | peak=0.774  rewires=781  rew_inf_ratio=1.516  | ETA: 1 min
#   [ 105/500]  β=0.233 γ=0.155 ρ=0.042  | peak=0.594  rewires=50  rew_inf_ratio=0.130  | ETA: 1 min
#   [ 106/500]  β=0.381 γ=0.112 ρ=0.218  | peak=0.701  rewires=173  rew_inf_ratio=0.526  | ETA: 1 min
#   [ 107/500]  β=0.337 γ=0.143 ρ=0.767  | peak=0.534  rewires=985  rew_inf_ratio=1.704  | ETA: 1 min
#   [ 108/500]  β=0.153 γ=0.087 ρ=0.224  | peak=0.663  rewires=382  rew_inf_ratio=0.549  | ETA: 1 min
#   [ 109/500]  β=0.207 γ=0.180 ρ=0.694  | peak=0.098  rewires=363  rew_inf_ratio=3.490  | ETA: 1 min
#   [ 110/500]  β=0.087 γ=0.118 ρ=0.530  | peak=0.071  rewires=180  rew_inf_ratio=3.000  | ETA: 1 min
#   [ 111/500]  β=0.076 γ=0.128 ρ=0.275  | peak=0.231  rewires=749  rew_inf_ratio=1.061  | ETA: 1 min
#   [ 112/500]  β=0.223 γ=0.177 ρ=0.660  | peak=0.265  rewires=1067  rew_inf_ratio=2.125  | ETA: 1 min
#   [ 113/500]  β=0.168 γ=0.149 ρ=0.372  | peak=0.449  rewires=636  rew_inf_ratio=1.200  | ETA: 1 min
#   [ 114/500]  β=0.398 γ=0.140 ρ=0.709  | peak=0.604  rewires=787  rew_inf_ratio=1.614  | ETA: 1 min
#   [ 115/500]  β=0.421 γ=0.030 ρ=0.334  | peak=0.924  rewires=290  rew_inf_ratio=0.709  | ETA: 1 min
#   [ 116/500]  β=0.142 γ=0.022 ρ=0.214  | peak=0.890  rewires=407  rew_inf_ratio=0.503  | ETA: 1 min
#   [ 117/500]  β=0.132 γ=0.028 ρ=0.645  | peak=0.499  rewires=1185  rew_inf_ratio=1.419  | ETA: 1 min
#   [ 118/500]  β=0.495 γ=0.044 ρ=0.075  | peak=0.893  rewires=53  rew_inf_ratio=0.152  | ETA: 1 min
#   [ 119/500]  β=0.061 γ=0.134 ρ=0.207  | peak=0.164  rewires=512  rew_inf_ratio=1.098  | ETA: 1 min
#   [ 120/500]  β=0.194 γ=0.152 ρ=0.741  | peak=0.084  rewires=228  rew_inf_ratio=4.690  | ETA: 1 min
#   [ 121/500]  β=0.179 γ=0.163 ρ=0.603  | peak=0.177  rewires=781  rew_inf_ratio=2.412  | ETA: 1 min
#   [ 122/500]  β=0.431 γ=0.186 ρ=0.298  | peak=0.638  rewires=230  rew_inf_ratio=0.776  | ETA: 1 min
#   [ 123/500]  β=0.225 γ=0.161 ρ=0.531  | peak=0.415  rewires=776  rew_inf_ratio=1.414  | ETA: 1 min
#   [ 124/500]  β=0.270 γ=0.027 ρ=0.380  | peak=0.901  rewires=455  rew_inf_ratio=0.815  | ETA: 1 min
#   [ 125/500]  β=0.163 γ=0.135 ρ=0.037  | peak=0.579  rewires=59  rew_inf_ratio=0.138  | ETA: 1 min
#   [ 126/500]  β=0.189 γ=0.104 ρ=0.455  | peak=0.599  rewires=776  rew_inf_ratio=1.055  | ETA: 1 min
#   [ 127/500]  β=0.307 γ=0.132 ρ=0.630  | peak=0.529  rewires=815  rew_inf_ratio=1.478  | ETA: 1 min
#   [ 128/500]  β=0.435 γ=0.116 ρ=0.679  | peak=0.667  rewires=699  rew_inf_ratio=1.573  | ETA: 1 min
#   [ 129/500]  β=0.071 γ=0.108 ρ=0.278  | peak=0.258  rewires=815  rew_inf_ratio=0.911  | ETA: 1 min
#   [ 130/500]  β=0.214 γ=0.114 ρ=0.201  | peak=0.680  rewires=241  rew_inf_ratio=0.482  | ETA: 1 min
#   [ 131/500]  β=0.246 γ=0.186 ρ=0.010  | peak=0.531  rewires=11  rew_inf_ratio=0.045  | ETA: 1 min
#   [ 132/500]  β=0.359 γ=0.049 ρ=0.683  | peak=0.849  rewires=840  rew_inf_ratio=1.456  | ETA: 1 min
#   [ 133/500]  β=0.115 γ=0.079 ρ=0.481  | peak=0.330  rewires=768  rew_inf_ratio=1.106  | ETA: 1 min
#   [ 134/500]  β=0.460 γ=0.124 ρ=0.014  | peak=0.741  rewires=9  rew_inf_ratio=0.035  | ETA: 1 min
#   [ 135/500]  β=0.111 γ=0.190 ρ=0.105  | peak=0.327  rewires=189  rew_inf_ratio=0.376  | ETA: 1 min
#   [ 136/500]  β=0.237 γ=0.180 ρ=0.378  | peak=0.437  rewires=473  rew_inf_ratio=1.048  | ETA: 1 min
#   [ 137/500]  β=0.146 γ=0.074 ρ=0.025  | peak=0.695  rewires=38  rew_inf_ratio=0.075  | ETA: 1 min
#   [ 138/500]  β=0.073 γ=0.025 ρ=0.240  | peak=0.812  rewires=823  rew_inf_ratio=0.585  | ETA: 1 min
#   [ 139/500]  β=0.487 γ=0.099 ρ=0.024  | peak=0.779  rewires=15  rew_inf_ratio=0.047  | ETA: 1 min
#   [ 140/500]  β=0.347 γ=0.175 ρ=0.355  | peak=0.563  rewires=344  rew_inf_ratio=0.911  | ETA: 1 min
#   [ 141/500]  β=0.075 γ=0.022 ρ=0.144  | peak=0.809  rewires=459  rew_inf_ratio=0.368  | ETA: 1 min
#   [ 142/500]  β=0.457 γ=0.162 ρ=0.098  | peak=0.677  rewires=68  rew_inf_ratio=0.266  | ETA: 1 min
#   [ 143/500]  β=0.283 γ=0.069 ρ=0.664  | peak=0.727  rewires=1027  rew_inf_ratio=1.421  | ETA: 1 min
#   [ 144/500]  β=0.255 γ=0.130 ρ=0.570  | peak=0.566  rewires=793  rew_inf_ratio=1.318  | ETA: 1 min
#   [ 145/500]  β=0.195 γ=0.146 ρ=0.757  | peak=0.086  rewires=247  rew_inf_ratio=4.407  | ETA: 1 min
#   [ 146/500]  β=0.353 γ=0.040 ρ=0.045  | peak=0.848  rewires=32  rew_inf_ratio=0.083  | ETA: 1 min
#   [ 147/500]  β=0.205 γ=0.117 ρ=0.401  | peak=0.598  rewires=597  rew_inf_ratio=0.945  | ETA: 1 min
#   [ 148/500]  β=0.225 γ=0.197 ρ=0.513  | peak=0.336  rewires=725  rew_inf_ratio=1.604  | ETA: 0 min
#   [ 149/500]  β=0.076 γ=0.048 ρ=0.391  | peak=0.495  rewires=1114  rew_inf_ratio=0.901  | ETA: 1 min
#   [ 150/500]  β=0.396 γ=0.195 ρ=0.683  | peak=0.540  rewires=755  rew_inf_ratio=1.743  | ETA: 0 min
#   >> Saved 150 results to pilot_results.csv
#   [ 151/500]  β=0.169 γ=0.155 ρ=0.295  | peak=0.462  rewires=470  rew_inf_ratio=0.920  | ETA: 0 min
#   [ 152/500]  β=0.363 γ=0.053 ρ=0.375  | peak=0.850  rewires=371  rew_inf_ratio=0.754  | ETA: 0 min
#   [ 153/500]  β=0.163 γ=0.139 ρ=0.465  | peak=0.430  rewires=869  rew_inf_ratio=1.307  | ETA: 0 min
#   [ 154/500]  β=0.441 γ=0.038 ρ=0.326  | peak=0.900  rewires=287  rew_inf_ratio=0.654  | ETA: 0 min
#   [ 155/500]  β=0.235 γ=0.123 ρ=0.784  | peak=0.284  rewires=970  rew_inf_ratio=2.060  | ETA: 0 min
#   [ 156/500]  β=0.119 γ=0.132 ρ=0.200  | peak=0.392  rewires=396  rew_inf_ratio=0.658  | ETA: 0 min
#   [ 157/500]  β=0.150 γ=0.053 ρ=0.676  | peak=0.195  rewires=568  rew_inf_ratio=1.913  | ETA: 0 min
#   [ 158/500]  β=0.166 γ=0.051 ρ=0.101  | peak=0.806  rewires=158  rew_inf_ratio=0.237  | ETA: 0 min
#   [ 159/500]  β=0.136 γ=0.127 ρ=0.164  | peak=0.519  rewires=276  rew_inf_ratio=0.547  | ETA: 0 min
#   [ 160/500]  β=0.091 γ=0.054 ρ=0.110  | peak=0.689  rewires=267  rew_inf_ratio=0.280  | ETA: 0 min
#   [ 161/500]  β=0.136 γ=0.162 ρ=0.497  | peak=0.147  rewires=558  rew_inf_ratio=2.265  | ETA: 0 min
#   [ 162/500]  β=0.306 γ=0.043 ρ=0.008  | peak=0.893  rewires=6  rew_inf_ratio=0.019  | ETA: 0 min
#   [ 163/500]  β=0.305 γ=0.070 ρ=0.359  | peak=0.812  rewires=389  rew_inf_ratio=0.815  | ETA: 0 min
#   [ 164/500]  β=0.142 γ=0.170 ρ=0.092  | peak=0.405  rewires=151  rew_inf_ratio=0.338  | ETA: 0 min
#   [ 165/500]  β=0.147 γ=0.036 ρ=0.692  | peak=0.350  rewires=827  rew_inf_ratio=1.651  | ETA: 0 min
#   [ 166/500]  β=0.055 γ=0.149 ρ=0.100  | peak=0.200  rewires=294  rew_inf_ratio=0.505  | ETA: 0 min
#   [ 167/500]  β=0.052 γ=0.179 ρ=0.270  | peak=0.046  rewires=112  rew_inf_ratio=1.957  | ETA: 0 min
#   [ 168/500]  β=0.449 γ=0.148 ρ=0.382  | peak=0.635  rewires=314  rew_inf_ratio=0.987  | ETA: 0 min
#   [ 169/500]  β=0.395 γ=0.023 ρ=0.610  | peak=0.940  rewires=698  rew_inf_ratio=1.282  | ETA: 0 min
#   [ 170/500]  β=0.136 γ=0.039 ρ=0.776  | peak=0.126  rewires=302  rew_inf_ratio=3.119  | ETA: 0 min
#   [ 171/500]  β=0.355 γ=0.142 ρ=0.358  | peak=0.654  rewires=337  rew_inf_ratio=0.869  | ETA: 0 min
#   [ 172/500]  β=0.347 γ=0.062 ρ=0.379  | peak=0.821  rewires=388  rew_inf_ratio=0.851  | ETA: 0 min
#   [ 173/500]  β=0.128 γ=0.161 ρ=0.318  | peak=0.329  rewires=590  rew_inf_ratio=1.061  | ETA: 0 min
#   [ 174/500]  β=0.061 γ=0.079 ρ=0.004  | peak=0.470  rewires=13  rew_inf_ratio=0.028  | ETA: 0 min
#   [ 175/500]  β=0.476 γ=0.174 ρ=0.033  | peak=0.671  rewires=22  rew_inf_ratio=0.075  | ETA: 0 min
#   [ 176/500]  β=0.191 γ=0.192 ρ=0.759  | peak=0.053  rewires=125  rew_inf_ratio=5.264  | ETA: 0 min
#   [ 177/500]  β=0.339 γ=0.065 ρ=0.005  | peak=0.818  rewires=3  rew_inf_ratio=0.012  | ETA: 0 min
#   [ 178/500]  β=0.152 γ=0.149 ρ=0.074  | peak=0.476  rewires=114  rew_inf_ratio=0.265  | ETA: 0 min
#   [ 179/500]  β=0.296 γ=0.036 ρ=0.241  | peak=0.886  rewires=251  rew_inf_ratio=0.503  | ETA: 0 min
#   [ 180/500]  β=0.325 γ=0.197 ρ=0.034  | peak=0.562  rewires=27  rew_inf_ratio=0.101  | ETA: 0 min
#   [ 181/500]  β=0.436 γ=0.181 ρ=0.330  | peak=0.623  rewires=273  rew_inf_ratio=0.891  | ETA: 0 min
#   [ 182/500]  β=0.192 γ=0.111 ρ=0.145  | peak=0.631  rewires=193  rew_inf_ratio=0.371  | ETA: 0 min
#   [ 183/500]  β=0.500 γ=0.098 ρ=0.384  | peak=0.756  rewires=309  rew_inf_ratio=0.907  | ETA: 0 min
#   [ 184/500]  β=0.219 γ=0.111 ρ=0.538  | peak=0.484  rewires=737  rew_inf_ratio=1.349  | ETA: 0 min
#   [ 185/500]  β=0.417 γ=0.105 ρ=0.397  | peak=0.746  rewires=334  rew_inf_ratio=0.895  | ETA: 0 min
#   [ 186/500]  β=0.488 γ=0.048 ρ=0.323  | peak=0.881  rewires=265  rew_inf_ratio=0.746  | ETA: 0 min
#   [ 187/500]  β=0.217 γ=0.119 ρ=0.579  | peak=0.527  rewires=881  rew_inf_ratio=1.351  | ETA: 0 min
#   [ 188/500]  β=0.153 γ=0.159 ρ=0.193  | peak=0.420  rewires=302  rew_inf_ratio=0.631  | ETA: 0 min
#   [ 189/500]  β=0.300 γ=0.124 ρ=0.395  | peak=0.661  rewires=426  rew_inf_ratio=1.003  | ETA: 0 min
#   [ 190/500]  β=0.206 γ=0.099 ρ=0.463  | peak=0.663  rewires=717  rew_inf_ratio=1.054  | ETA: 0 min
#   [ 191/500]  β=0.384 γ=0.136 ρ=0.048  | peak=0.687  rewires=31  rew_inf_ratio=0.122  | ETA: 0 min
#   [ 192/500]  β=0.436 γ=0.073 ρ=0.605  | peak=0.778  rewires=599  rew_inf_ratio=1.333  | ETA: 0 min
#   [ 193/500]  β=0.152 γ=0.048 ρ=0.606  | peak=0.472  rewires=914  rew_inf_ratio=1.352  | ETA: 0 min
#   [ 194/500]  β=0.458 γ=0.089 ρ=0.235  | peak=0.801  rewires=182  rew_inf_ratio=0.610  | ETA: 0 min
#   [ 195/500]  β=0.146 γ=0.107 ρ=0.403  | peak=0.561  rewires=754  rew_inf_ratio=0.979  | ETA: 0 min
#   [ 196/500]  β=0.355 γ=0.157 ρ=0.514  | peak=0.575  rewires=545  rew_inf_ratio=1.320  | ETA: 0 min
#   [ 197/500]  β=0.136 γ=0.052 ρ=0.637  | peak=0.664  rewires=1627  rew_inf_ratio=1.264  | ETA: 0 min
#   [ 198/500]  β=0.313 γ=0.164 ρ=0.370  | peak=0.571  rewires=376  rew_inf_ratio=0.944  | ETA: 0 min
#   [ 199/500]  β=0.500 γ=0.197 ρ=0.178  | peak=0.583  rewires=109  rew_inf_ratio=0.460  | ETA: 0 min
#   [ 200/500]  β=0.461 γ=0.052 ρ=0.704  | peak=0.853  rewires=754  rew_inf_ratio=1.523  | ETA: 0 min
#   >> Saved 200 results to pilot_results.csv
#   [ 201/500]  β=0.263 γ=0.186 ρ=0.133  | peak=0.538  rewires=135  rew_inf_ratio=0.359  | ETA: 0 min
#   [ 202/500]  β=0.248 γ=0.091 ρ=0.630  | peak=0.695  rewires=912  rew_inf_ratio=1.396  | ETA: 0 min
#   [ 203/500]  β=0.099 γ=0.021 ρ=0.335  | peak=0.876  rewires=951  rew_inf_ratio=0.709  | ETA: 0 min
#   [ 204/500]  β=0.105 γ=0.088 ρ=0.722  | peak=0.063  rewires=119  rew_inf_ratio=4.190  | ETA: 0 min
#   [ 205/500]  β=0.284 γ=0.076 ρ=0.384  | peak=0.795  rewires=459  rew_inf_ratio=0.844  | ETA: 0 min
#   [ 206/500]  β=0.306 γ=0.032 ρ=0.412  | peak=0.888  rewires=501  rew_inf_ratio=0.937  | ETA: 0 min
#   [ 207/500]  β=0.060 γ=0.191 ρ=0.793  | peak=0.031  rewires=51  rew_inf_ratio=6.548  | ETA: 0 min
#   [ 208/500]  β=0.179 γ=0.021 ρ=0.517  | peak=0.889  rewires=988  rew_inf_ratio=1.051  | ETA: 0 min
#   [ 209/500]  β=0.172 γ=0.087 ρ=0.528  | peak=0.593  rewires=1063  rew_inf_ratio=1.224  | ETA: 0 min
#   [ 210/500]  β=0.238 γ=0.146 ρ=0.046  | peak=0.621  rewires=53  rew_inf_ratio=0.159  | ETA: 0 min
#   [ 211/500]  β=0.411 γ=0.107 ρ=0.485  | peak=0.716  rewires=468  rew_inf_ratio=1.070  | ETA: 0 min
#   [ 212/500]  β=0.114 γ=0.035 ρ=0.675  | peak=0.062  rewires=124  rew_inf_ratio=4.403  | ETA: 0 min
#   [ 213/500]  β=0.357 γ=0.189 ρ=0.400  | peak=0.486  rewires=349  rew_inf_ratio=1.099  | ETA: 0 min
#   [ 214/500]  β=0.356 γ=0.105 ρ=0.042  | peak=0.729  rewires=33  rew_inf_ratio=0.095  | ETA: 0 min
#   [ 215/500]  β=0.312 γ=0.023 ρ=0.212  | peak=0.934  rewires=212  rew_inf_ratio=0.457  | ETA: 0 min
#   [ 216/500]  β=0.207 γ=0.199 ρ=0.209  | peak=0.429  rewires=256  rew_inf_ratio=0.632  | ETA: 0 min
#   [ 217/500]  β=0.166 γ=0.194 ρ=0.076  | peak=0.436  rewires=94  rew_inf_ratio=0.280  | ETA: 0 min
#   [ 218/500]  β=0.377 γ=0.107 ρ=0.147  | peak=0.733  rewires=111  rew_inf_ratio=0.312  | ETA: 0 min
#   [ 219/500]  β=0.340 γ=0.178 ρ=0.364  | peak=0.559  rewires=341  rew_inf_ratio=0.912  | ETA: 0 min
#   [ 220/500]  β=0.178 γ=0.161 ρ=0.616  | peak=0.200  rewires=803  rew_inf_ratio=2.120  | ETA: 0 min
#   [ 221/500]  β=0.343 γ=0.104 ρ=0.614  | peak=0.718  rewires=702  rew_inf_ratio=1.468  | ETA: 0 min
#   [ 222/500]  β=0.368 γ=0.161 ρ=0.575  | peak=0.570  rewires=665  rew_inf_ratio=1.446  | ETA: 0 min
#   [ 223/500]  β=0.176 γ=0.122 ρ=0.793  | peak=0.087  rewires=206  rew_inf_ratio=4.609  | ETA: 0 min
#   [ 224/500]  β=0.113 γ=0.043 ρ=0.470  | peak=0.718  rewires=1220  rew_inf_ratio=0.979  | ETA: 0 min
#   [ 225/500]  β=0.220 γ=0.159 ρ=0.684  | peak=0.241  rewires=742  rew_inf_ratio=2.071  | ETA: 0 min
#   [ 226/500]  β=0.473 γ=0.144 ρ=0.236  | peak=0.668  rewires=169  rew_inf_ratio=0.623  | ETA: 0 min
#   [ 227/500]  β=0.066 γ=0.103 ρ=0.213  | peak=0.329  rewires=643  rew_inf_ratio=0.757  | ETA: 0 min
#   [ 228/500]  β=0.210 γ=0.086 ρ=0.263  | peak=0.744  rewires=357  rew_inf_ratio=0.644  | ETA: 0 min
#   [ 229/500]  β=0.365 γ=0.157 ρ=0.387  | peak=0.624  rewires=360  rew_inf_ratio=0.912  | ETA: 0 min
#   [ 230/500]  β=0.115 γ=0.100 ρ=0.334  | peak=0.509  rewires=701  rew_inf_ratio=0.825  | ETA: 0 min
#   [ 231/500]  β=0.297 γ=0.123 ρ=0.264  | peak=0.643  rewires=283  rew_inf_ratio=0.639  | ETA: 0 min
#   [ 232/500]  β=0.113 γ=0.092 ρ=0.065  | peak=0.602  rewires=136  rew_inf_ratio=0.223  | ETA: 0 min
#   [ 233/500]  β=0.417 γ=0.161 ρ=0.293  | peak=0.618  rewires=240  rew_inf_ratio=0.798  | ETA: 0 min
#   [ 234/500]  β=0.205 γ=0.104 ρ=0.244  | peak=0.660  rewires=339  rew_inf_ratio=0.661  | ETA: 0 min
#   [ 235/500]  β=0.443 γ=0.076 ρ=0.031  | peak=0.831  rewires=19  rew_inf_ratio=0.063  | ETA: 0 min
#   [ 236/500]  β=0.253 γ=0.118 ρ=0.666  | peak=0.591  rewires=989  rew_inf_ratio=1.557  | ETA: 0 min
#   [ 237/500]  β=0.352 γ=0.168 ρ=0.241  | peak=0.637  rewires=193  rew_inf_ratio=0.531  | ETA: 0 min
#   [ 238/500]  β=0.097 γ=0.177 ρ=0.401  | peak=0.091  rewires=480  rew_inf_ratio=2.066  | ETA: 0 min
#   [ 239/500]  β=0.310 γ=0.064 ρ=0.218  | peak=0.810  rewires=212  rew_inf_ratio=0.527  | ETA: 0 min
#   [ 240/500]  β=0.252 γ=0.163 ρ=0.131  | peak=0.569  rewires=128  rew_inf_ratio=0.350  | ETA: 0 min
#   [ 241/500]  β=0.176 γ=0.023 ρ=0.438  | peak=0.898  rewires=786  rew_inf_ratio=0.918  | ETA: 0 min
#   [ 242/500]  β=0.273 γ=0.138 ρ=0.632  | peak=0.524  rewires=919  rew_inf_ratio=1.511  | ETA: 0 min
#   [ 243/500]  β=0.131 γ=0.087 ρ=0.468  | peak=0.544  rewires=1059  rew_inf_ratio=0.987  | ETA: 0 min
#   [ 244/500]  β=0.452 γ=0.199 ρ=0.369  | peak=0.569  rewires=289  rew_inf_ratio=0.972  | ETA: 0 min
#   [ 245/500]  β=0.274 γ=0.183 ρ=0.306  | peak=0.523  rewires=321  rew_inf_ratio=0.776  | ETA: 0 min
#   [ 246/500]  β=0.463 γ=0.056 ρ=0.383  | peak=0.857  rewires=321  rew_inf_ratio=0.814  | ETA: 0 min
#   [ 247/500]  β=0.223 γ=0.021 ρ=0.212  | peak=0.895  rewires=278  rew_inf_ratio=0.492  | ETA: 0 min
#   [ 248/500]  β=0.288 γ=0.117 ρ=0.553  | peak=0.632  rewires=708  rew_inf_ratio=1.277  | ETA: 0 min
#   [ 249/500]  β=0.314 γ=0.021 ρ=0.213  | peak=0.939  rewires=222  rew_inf_ratio=0.443  | ETA: 0 min
#   [ 250/500]  β=0.209 γ=0.128 ρ=0.276  | peak=0.589  rewires=387  rew_inf_ratio=0.728  | ETA: 0 min
#   >> Saved 250 results to pilot_results.csv
#   [ 251/500]  β=0.080 γ=0.087 ρ=0.776  | peak=0.049  rewires=115  rew_inf_ratio=5.837  | ETA: 0 min
#   [ 252/500]  β=0.291 γ=0.072 ρ=0.067  | peak=0.790  rewires=63  rew_inf_ratio=0.163  | ETA: 0 min
#   [ 253/500]  β=0.061 γ=0.133 ρ=0.184  | peak=0.163  rewires=462  rew_inf_ratio=0.877  | ETA: 0 min
#   [ 254/500]  β=0.260 γ=0.022 ρ=0.472  | peak=0.899  rewires=654  rew_inf_ratio=0.993  | ETA: 0 min
#   [ 255/500]  β=0.464 γ=0.101 ρ=0.135  | peak=0.757  rewires=96  rew_inf_ratio=0.322  | ETA: 0 min
#   [ 256/500]  β=0.071 γ=0.078 ρ=0.332  | peak=0.258  rewires=835  rew_inf_ratio=0.903  | ETA: 0 min
#   [ 257/500]  β=0.162 γ=0.187 ρ=0.602  | peak=0.078  rewires=270  rew_inf_ratio=3.436  | ETA: 0 min
#   [ 258/500]  β=0.472 γ=0.117 ρ=0.677  | peak=0.701  rewires=678  rew_inf_ratio=1.589  | ETA: 0 min
#   [ 259/500]  β=0.251 γ=0.103 ρ=0.111  | peak=0.724  rewires=122  rew_inf_ratio=0.305  | ETA: 0 min
#   [ 260/500]  β=0.292 γ=0.114 ρ=0.254  | peak=0.676  rewires=262  rew_inf_ratio=0.646  | ETA: 0 min
#   [ 261/500]  β=0.441 γ=0.132 ρ=0.209  | peak=0.710  rewires=165  rew_inf_ratio=0.517  | ETA: 0 min
#   [ 262/500]  β=0.353 γ=0.076 ρ=0.109  | peak=0.804  rewires=96  rew_inf_ratio=0.286  | ETA: 0 min
#   [ 263/500]  β=0.379 γ=0.183 ρ=0.187  | peak=0.538  rewires=146  rew_inf_ratio=0.533  | ETA: 0 min
#   [ 264/500]  β=0.345 γ=0.116 ρ=0.487  | peak=0.662  rewires=525  rew_inf_ratio=1.148  | ETA: 0 min
#   [ 265/500]  β=0.193 γ=0.107 ρ=0.353  | peak=0.608  rewires=547  rew_inf_ratio=0.885  | ETA: 0 min
#   [ 266/500]  β=0.327 γ=0.145 ρ=0.511  | peak=0.603  rewires=534  rew_inf_ratio=1.179  | ETA: 0 min
#   [ 267/500]  β=0.242 γ=0.100 ρ=0.697  | peak=0.584  rewires=1188  rew_inf_ratio=1.592  | ETA: 0 min
#   [ 268/500]  β=0.092 γ=0.087 ρ=0.056  | peak=0.581  rewires=134  rew_inf_ratio=0.188  | ETA: 0 min
#   [ 269/500]  β=0.174 γ=0.091 ρ=0.256  | peak=0.618  rewires=424  rew_inf_ratio=0.672  | ETA: 0 min
#   [ 270/500]  β=0.456 γ=0.028 ρ=0.065  | peak=0.927  rewires=47  rew_inf_ratio=0.140  | ETA: 0 min
#   [ 271/500]  β=0.379 γ=0.190 ρ=0.322  | peak=0.602  rewires=276  rew_inf_ratio=0.857  | ETA: 0 min
#   [ 272/500]  β=0.314 γ=0.190 ρ=0.523  | peak=0.441  rewires=585  rew_inf_ratio=1.351  | ETA: 0 min
#   [ 273/500]  β=0.151 γ=0.152 ρ=0.707  | peak=0.077  rewires=220  rew_inf_ratio=4.532  | ETA: 0 min
#   [ 274/500]  β=0.187 γ=0.113 ρ=0.490  | peak=0.567  rewires=858  rew_inf_ratio=1.203  | ETA: 0 min
#   [ 275/500]  β=0.360 γ=0.131 ρ=0.646  | peak=0.610  rewires=778  rew_inf_ratio=1.536  | ETA: 0 min
#   [ 276/500]  β=0.499 γ=0.033 ρ=0.601  | peak=0.911  rewires=543  rew_inf_ratio=1.194  | ETA: 0 min
#   [ 277/500]  β=0.402 γ=0.193 ρ=0.138  | peak=0.608  rewires=110  rew_inf_ratio=0.380  | ETA: 0 min
#   [ 278/500]  β=0.140 γ=0.116 ρ=0.062  | peak=0.583  rewires=99  rew_inf_ratio=0.189  | ETA: 0 min
#   [ 279/500]  β=0.130 γ=0.114 ρ=0.067  | peak=0.580  rewires=118  rew_inf_ratio=0.198  | ETA: 0 min
#   [ 280/500]  β=0.338 γ=0.147 ρ=0.505  | peak=0.587  rewires=565  rew_inf_ratio=1.312  | ETA: 0 min
#   [ 281/500]  β=0.449 γ=0.169 ρ=0.608  | peak=0.567  rewires=554  rew_inf_ratio=1.469  | ETA: 0 min
#   [ 282/500]  β=0.408 γ=0.077 ρ=0.093  | peak=0.835  rewires=73  rew_inf_ratio=0.187  | ETA: 0 min
#   [ 283/500]  β=0.408 γ=0.189 ρ=0.091  | peak=0.594  rewires=64  rew_inf_ratio=0.251  | ETA: 0 min
#   [ 284/500]  β=0.130 γ=0.091 ρ=0.418  | peak=0.546  rewires=924  rew_inf_ratio=1.092  | ETA: 0 min
#   [ 285/500]  β=0.205 γ=0.127 ρ=0.174  | peak=0.596  rewires=216  rew_inf_ratio=0.502  | ETA: 0 min
#   [ 286/500]  β=0.167 γ=0.187 ρ=0.206  | peak=0.411  rewires=294  rew_inf_ratio=0.676  | ETA: 0 min
#   [ 287/500]  β=0.447 γ=0.067 ρ=0.233  | peak=0.830  rewires=187  rew_inf_ratio=0.528  | ETA: 0 min
#   [ 288/500]  β=0.281 γ=0.132 ρ=0.705  | peak=0.478  rewires=1048  rew_inf_ratio=1.603  | ETA: 0 min
#   [ 289/500]  β=0.342 γ=0.034 ρ=0.270  | peak=0.913  rewires=267  rew_inf_ratio=0.537  | ETA: 0 min
#   [ 290/500]  β=0.425 γ=0.142 ρ=0.011  | peak=0.680  rewires=10  rew_inf_ratio=0.038  | ETA: 0 min
#   [ 291/500]  β=0.111 γ=0.106 ρ=0.210  | peak=0.529  rewires=474  rew_inf_ratio=0.590  | ETA: 0 min
#   [ 292/500]  β=0.111 γ=0.115 ρ=0.405  | peak=0.330  rewires=1007  rew_inf_ratio=1.100  | ETA: 0 min
#   [ 293/500]  β=0.383 γ=0.033 ρ=0.447  | peak=0.903  rewires=441  rew_inf_ratio=0.956  | ETA: 0 min
#   [ 294/500]  β=0.424 γ=0.037 ρ=0.396  | peak=0.905  rewires=345  rew_inf_ratio=0.822  | ETA: 0 min
#   [ 295/500]  β=0.206 γ=0.132 ρ=0.337  | peak=0.565  rewires=474  rew_inf_ratio=0.945  | ETA: 0 min
#   [ 296/500]  β=0.399 γ=0.195 ρ=0.496  | peak=0.538  rewires=453  rew_inf_ratio=1.318  | ETA: 0 min
#   [ 297/500]  β=0.226 γ=0.190 ρ=0.373  | peak=0.442  rewires=454  rew_inf_ratio=1.057  | ETA: 0 min
#   [ 298/500]  β=0.377 γ=0.163 ρ=0.010  | peak=0.658  rewires=4  rew_inf_ratio=0.018  | ETA: 0 min
#   [ 299/500]  β=0.118 γ=0.123 ρ=0.410  | peak=0.360  rewires=975  rew_inf_ratio=1.100  | ETA: 0 min
#   [ 300/500]  β=0.258 γ=0.116 ρ=0.264  | peak=0.695  rewires=299  rew_inf_ratio=0.650  | ETA: 0 min
#   >> Saved 300 results to pilot_results.csv
#   [ 301/500]  β=0.191 γ=0.165 ρ=0.175  | peak=0.482  rewires=230  rew_inf_ratio=0.541  | ETA: 0 min
#   [ 302/500]  β=0.140 γ=0.074 ρ=0.146  | peak=0.657  rewires=257  rew_inf_ratio=0.388  | ETA: 0 min
#   [ 303/500]  β=0.456 γ=0.137 ρ=0.443  | peak=0.684  rewires=372  rew_inf_ratio=1.023  | ETA: 0 min
#   [ 304/500]  β=0.104 γ=0.170 ρ=0.557  | peak=0.073  rewires=249  rew_inf_ratio=3.589  | ETA: 0 min
#   [ 305/500]  β=0.421 γ=0.050 ρ=0.583  | peak=0.851  rewires=606  rew_inf_ratio=1.273  | ETA: 0 min
#   [ 306/500]  β=0.228 γ=0.089 ρ=0.475  | peak=0.662  rewires=669  rew_inf_ratio=1.076  | ETA: 0 min
#   [ 307/500]  β=0.402 γ=0.065 ρ=0.757  | peak=0.796  rewires=901  rew_inf_ratio=1.568  | ETA: 0 min
#   [ 308/500]  β=0.380 γ=0.144 ρ=0.786  | peak=0.536  rewires=973  rew_inf_ratio=1.674  | ETA: 0 min
#   [ 309/500]  β=0.400 γ=0.165 ρ=0.748  | peak=0.542  rewires=868  rew_inf_ratio=1.851  | ETA: 0 min
#   [ 310/500]  β=0.151 γ=0.144 ρ=0.340  | peak=0.427  rewires=609  rew_inf_ratio=0.920  | ETA: 0 min
#   [ 311/500]  β=0.473 γ=0.083 ρ=0.039  | peak=0.824  rewires=26  rew_inf_ratio=0.086  | ETA: 0 min
#   [ 312/500]  β=0.371 γ=0.185 ρ=0.538  | peak=0.525  rewires=513  rew_inf_ratio=1.305  | ETA: 0 min
#   [ 313/500]  β=0.064 γ=0.165 ρ=0.051  | peak=0.249  rewires=140  rew_inf_ratio=0.269  | ETA: 0 min
#   [ 314/500]  β=0.324 γ=0.072 ρ=0.668  | peak=0.770  rewires=849  rew_inf_ratio=1.453  | ETA: 0 min
#   [ 315/500]  β=0.471 γ=0.065 ρ=0.077  | peak=0.861  rewires=63  rew_inf_ratio=0.200  | ETA: 0 min
#   [ 316/500]  β=0.195 γ=0.180 ρ=0.189  | peak=0.489  rewires=254  rew_inf_ratio=0.571  | ETA: 0 min
#   [ 317/500]  β=0.231 γ=0.049 ρ=0.280  | peak=0.832  rewires=356  rew_inf_ratio=0.605  | ETA: 0 min
#   [ 318/500]  β=0.382 γ=0.050 ρ=0.627  | peak=0.856  rewires=694  rew_inf_ratio=1.301  | ETA: 0 min
#   [ 319/500]  β=0.439 γ=0.040 ρ=0.322  | peak=0.906  rewires=249  rew_inf_ratio=0.628  | ETA: 0 min
#   [ 320/500]  β=0.341 γ=0.132 ρ=0.670  | peak=0.606  rewires=816  rew_inf_ratio=1.568  | ETA: 0 min
#   [ 321/500]  β=0.063 γ=0.069 ρ=0.407  | peak=0.087  rewires=239  rew_inf_ratio=2.103  | ETA: 0 min
#   [ 322/500]  β=0.434 γ=0.126 ρ=0.363  | peak=0.683  rewires=300  rew_inf_ratio=0.824  | ETA: 0 min
#   [ 323/500]  β=0.277 γ=0.130 ρ=0.165  | peak=0.649  rewires=170  rew_inf_ratio=0.427  | ETA: 0 min
#   [ 324/500]  β=0.232 γ=0.174 ρ=0.208  | peak=0.563  rewires=251  rew_inf_ratio=0.593  | ETA: 0 min
#   [ 325/500]  β=0.433 γ=0.165 ρ=0.135  | peak=0.648  rewires=90  rew_inf_ratio=0.343  | ETA: 0 min
#   [ 326/500]  β=0.181 γ=0.140 ρ=0.332  | peak=0.497  rewires=494  rew_inf_ratio=0.885  | ETA: 0 min
#   [ 327/500]  β=0.351 γ=0.038 ρ=0.231  | peak=0.902  rewires=216  rew_inf_ratio=0.501  | ETA: 0 min
#   [ 328/500]  β=0.061 γ=0.163 ρ=0.225  | peak=0.060  rewires=245  rew_inf_ratio=1.467  | ETA: 0 min
#   [ 329/500]  β=0.488 γ=0.163 ρ=0.405  | peak=0.649  rewires=294  rew_inf_ratio=0.926  | ETA: 0 min
#   [ 330/500]  β=0.417 γ=0.072 ρ=0.506  | peak=0.809  rewires=498  rew_inf_ratio=1.098  | ETA: 0 min
#   [ 331/500]  β=0.150 γ=0.022 ρ=0.607  | peak=0.865  rewires=1406  rew_inf_ratio=1.149  | ETA: 0 min
#   [ 332/500]  β=0.382 γ=0.186 ρ=0.716  | peak=0.484  rewires=827  rew_inf_ratio=1.758  | ETA: 0 min
#   [ 333/500]  β=0.426 γ=0.157 ρ=0.393  | peak=0.631  rewires=314  rew_inf_ratio=0.922  | ETA: 0 min
#   [ 334/500]  β=0.309 γ=0.086 ρ=0.040  | peak=0.767  rewires=38  rew_inf_ratio=0.100  | ETA: 0 min
#   [ 335/500]  β=0.477 γ=0.166 ρ=0.241  | peak=0.636  rewires=171  rew_inf_ratio=0.599  | ETA: 0 min
#   [ 336/500]  β=0.447 γ=0.047 ρ=0.517  | peak=0.867  rewires=485  rew_inf_ratio=1.141  | ETA: 0 min
#   [ 337/500]  β=0.472 γ=0.130 ρ=0.387  | peak=0.696  rewires=306  rew_inf_ratio=0.865  | ETA: 0 min
#   [ 338/500]  β=0.380 γ=0.104 ρ=0.192  | peak=0.735  rewires=164  rew_inf_ratio=0.438  | ETA: 0 min
#   [ 339/500]  β=0.349 γ=0.036 ρ=0.141  | peak=0.895  rewires=134  rew_inf_ratio=0.308  | ETA: 0 min
#   [ 340/500]  β=0.417 γ=0.188 ρ=0.403  | peak=0.569  rewires=339  rew_inf_ratio=1.037  | ETA: 0 min
#   [ 341/500]  β=0.167 γ=0.120 ρ=0.460  | peak=0.540  rewires=865  rew_inf_ratio=1.150  | ETA: 0 min
#   [ 342/500]  β=0.397 γ=0.083 ρ=0.344  | peak=0.783  rewires=326  rew_inf_ratio=0.799  | ETA: 0 min
#   [ 343/500]  β=0.137 γ=0.198 ρ=0.498  | peak=0.099  rewires=402  rew_inf_ratio=2.525  | ETA: 0 min
#   [ 344/500]  β=0.238 γ=0.051 ρ=0.720  | peak=0.787  rewires=1210  rew_inf_ratio=1.445  | ETA: 0 min
#   [ 345/500]  β=0.238 γ=0.134 ρ=0.407  | peak=0.609  rewires=555  rew_inf_ratio=0.984  | ETA: 0 min
#   [ 346/500]  β=0.214 γ=0.199 ρ=0.237  | peak=0.447  rewires=291  rew_inf_ratio=0.732  | ETA: 0 min
#   [ 347/500]  β=0.481 γ=0.021 ρ=0.098  | peak=0.945  rewires=71  rew_inf_ratio=0.197  | ETA: 0 min
#   [ 348/500]  β=0.208 γ=0.122 ρ=0.585  | peak=0.491  rewires=940  rew_inf_ratio=1.517  | ETA: 0 min
#   [ 349/500]  β=0.285 γ=0.074 ρ=0.358  | peak=0.789  rewires=396  rew_inf_ratio=0.856  | ETA: 0 min
#   [ 350/500]  β=0.487 γ=0.094 ρ=0.341  | peak=0.784  rewires=250  rew_inf_ratio=0.795  | ETA: 0 min
#   >> Saved 350 results to pilot_results.csv
#   [ 351/500]  β=0.191 γ=0.149 ρ=0.625  | peak=0.244  rewires=958  rew_inf_ratio=1.971  | ETA: 0 min
#   [ 352/500]  β=0.421 γ=0.172 ρ=0.786  | peak=0.511  rewires=939  rew_inf_ratio=1.771  | ETA: 0 min
#   [ 353/500]  β=0.281 γ=0.039 ρ=0.570  | peak=0.847  rewires=728  rew_inf_ratio=1.201  | ETA: 0 min
#   [ 354/500]  β=0.251 γ=0.177 ρ=0.628  | peak=0.336  rewires=913  rew_inf_ratio=1.545  | ETA: 0 min
#   [ 355/500]  β=0.135 γ=0.103 ρ=0.368  | peak=0.539  rewires=722  rew_inf_ratio=0.928  | ETA: 0 min
#   [ 356/500]  β=0.413 γ=0.152 ρ=0.618  | peak=0.607  rewires=618  rew_inf_ratio=1.478  | ETA: 0 min
#   [ 357/500]  β=0.296 γ=0.180 ρ=0.349  | peak=0.508  rewires=370  rew_inf_ratio=0.915  | ETA: 0 min
#   [ 358/500]  β=0.411 γ=0.061 ρ=0.303  | peak=0.862  rewires=258  rew_inf_ratio=0.622  | ETA: 0 min
#   [ 359/500]  β=0.455 γ=0.178 ρ=0.329  | peak=0.616  rewires=246  rew_inf_ratio=0.804  | ETA: 0 min
#   [ 360/500]  β=0.184 γ=0.124 ρ=0.579  | peak=0.315  rewires=764  rew_inf_ratio=1.670  | ETA: 0 min
#   [ 361/500]  β=0.295 γ=0.069 ρ=0.381  | peak=0.787  rewires=440  rew_inf_ratio=0.842  | ETA: 0 min
#   [ 362/500]  β=0.184 γ=0.099 ρ=0.155  | peak=0.661  rewires=241  rew_inf_ratio=0.474  | ETA: 0 min
#   [ 363/500]  β=0.308 γ=0.184 ρ=0.490  | peak=0.471  rewires=536  rew_inf_ratio=1.372  | ETA: 0 min
#   [ 364/500]  β=0.117 γ=0.092 ρ=0.438  | peak=0.346  rewires=893  rew_inf_ratio=1.249  | ETA: 0 min
#   [ 365/500]  β=0.426 γ=0.041 ρ=0.314  | peak=0.883  rewires=275  rew_inf_ratio=0.723  | ETA: 0 min
#   [ 366/500]  β=0.274 γ=0.025 ρ=0.380  | peak=0.894  rewires=458  rew_inf_ratio=0.824  | ETA: 0 min
#   [ 367/500]  β=0.394 γ=0.030 ρ=0.018  | peak=0.925  rewires=16  rew_inf_ratio=0.044  | ETA: 0 min
#   [ 368/500]  β=0.056 γ=0.151 ρ=0.198  | peak=0.087  rewires=264  rew_inf_ratio=1.207  | ETA: 0 min
#   [ 369/500]  β=0.457 γ=0.154 ρ=0.553  | peak=0.640  rewires=489  rew_inf_ratio=1.402  | ETA: 0 min
#   [ 370/500]  β=0.081 γ=0.025 ρ=0.362  | peak=0.815  rewires=1194  rew_inf_ratio=0.750  | ETA: 0 min
#   [ 371/500]  β=0.293 γ=0.125 ρ=0.614  | peak=0.577  rewires=766  rew_inf_ratio=1.435  | ETA: 0 min
#   [ 372/500]  β=0.423 γ=0.025 ρ=0.699  | peak=0.915  rewires=762  rew_inf_ratio=1.455  | ETA: 0 min
#   [ 373/500]  β=0.493 γ=0.059 ρ=0.574  | peak=0.841  rewires=546  rew_inf_ratio=1.278  | ETA: 0 min
#   [ 374/500]  β=0.376 γ=0.085 ρ=0.509  | peak=0.764  rewires=567  rew_inf_ratio=1.194  | ETA: 0 min
#   [ 375/500]  β=0.308 γ=0.043 ρ=0.371  | peak=0.867  rewires=447  rew_inf_ratio=0.869  | ETA: 0 min
#   [ 376/500]  β=0.378 γ=0.188 ρ=0.360  | peak=0.562  rewires=310  rew_inf_ratio=0.927  | ETA: 0 min
#   [ 377/500]  β=0.363 γ=0.072 ρ=0.658  | peak=0.774  rewires=761  rew_inf_ratio=1.377  | ETA: 0 min
#   [ 378/500]  β=0.318 γ=0.086 ρ=0.429  | peak=0.739  rewires=446  rew_inf_ratio=0.980  | ETA: 0 min
#   [ 379/500]  β=0.122 γ=0.079 ρ=0.140  | peak=0.685  rewires=271  rew_inf_ratio=0.401  | ETA: 0 min
#   [ 380/500]  β=0.419 γ=0.069 ρ=0.144  | peak=0.828  rewires=109  rew_inf_ratio=0.329  | ETA: 0 min
#   [ 381/500]  β=0.353 γ=0.107 ρ=0.724  | peak=0.627  rewires=872  rew_inf_ratio=1.721  | ETA: 0 min
#   [ 382/500]  β=0.453 γ=0.105 ρ=0.068  | peak=0.735  rewires=53  rew_inf_ratio=0.203  | ETA: 0 min
#   [ 383/500]  β=0.335 γ=0.084 ρ=0.769  | peak=0.699  rewires=1118  rew_inf_ratio=1.644  | ETA: 0 min
#   [ 384/500]  β=0.457 γ=0.162 ρ=0.134  | peak=0.666  rewires=89  rew_inf_ratio=0.336  | ETA: 0 min
#   [ 385/500]  β=0.212 γ=0.190 ρ=0.753  | peak=0.122  rewires=417  rew_inf_ratio=3.566  | ETA: 0 min
#   [ 386/500]  β=0.179 γ=0.022 ρ=0.187  | peak=0.894  rewires=289  rew_inf_ratio=0.455  | ETA: 0 min
#   [ 387/500]  β=0.112 γ=0.046 ρ=0.450  | peak=0.729  rewires=1145  rew_inf_ratio=0.848  | ETA: 0 min
#   [ 388/500]  β=0.188 γ=0.100 ρ=0.218  | peak=0.657  rewires=324  rew_inf_ratio=0.583  | ETA: 0 min
#   [ 389/500]  β=0.262 γ=0.179 ρ=0.472  | peak=0.452  rewires=601  rew_inf_ratio=1.330  | ETA: 0 min
#   [ 390/500]  β=0.284 γ=0.061 ρ=0.318  | peak=0.804  rewires=372  rew_inf_ratio=0.700  | ETA: 0 min
#   [ 391/500]  β=0.176 γ=0.113 ρ=0.130  | peak=0.613  rewires=178  rew_inf_ratio=0.357  | ETA: 0 min
#   [ 392/500]  β=0.469 γ=0.075 ρ=0.393  | peak=0.815  rewires=318  rew_inf_ratio=0.817  | ETA: 0 min
#   [ 393/500]  β=0.118 γ=0.092 ρ=0.162  | peak=0.601  rewires=329  rew_inf_ratio=0.446  | ETA: 0 min
#   [ 394/500]  β=0.350 γ=0.186 ρ=0.136  | peak=0.606  rewires=105  rew_inf_ratio=0.347  | ETA: 0 min
#   [ 395/500]  β=0.289 γ=0.115 ρ=0.254  | peak=0.666  rewires=268  rew_inf_ratio=0.655  | ETA: 0 min
#   [ 396/500]  β=0.200 γ=0.024 ρ=0.423  | peak=0.897  rewires=678  rew_inf_ratio=0.846  | ETA: 0 min
#   [ 397/500]  β=0.263 γ=0.137 ρ=0.796  | peak=0.366  rewires=1179  rew_inf_ratio=2.019  | ETA: 0 min
#   [ 398/500]  β=0.341 γ=0.026 ρ=0.739  | peak=0.913  rewires=959  rew_inf_ratio=1.441  | ETA: 0 min
#   [ 399/500]  β=0.498 γ=0.188 ρ=0.066  | peak=0.627  rewires=44  rew_inf_ratio=0.188  | ETA: 0 min
#   [ 400/500]  β=0.241 γ=0.190 ρ=0.651  | peak=0.281  rewires=967  rew_inf_ratio=1.847  | ETA: 0 min
#   >> Saved 400 results to pilot_results.csv
#   [ 401/500]  β=0.318 γ=0.149 ρ=0.625  | peak=0.557  rewires=779  rew_inf_ratio=1.503  | ETA: 0 min
#   [ 402/500]  β=0.149 γ=0.147 ρ=0.140  | peak=0.511  rewires=229  rew_inf_ratio=0.425  | ETA: 0 min
#   [ 403/500]  β=0.367 γ=0.070 ρ=0.705  | peak=0.764  rewires=883  rew_inf_ratio=1.539  | ETA: 0 min
#   [ 404/500]  β=0.262 γ=0.055 ρ=0.256  | peak=0.804  rewires=278  rew_inf_ratio=0.590  | ETA: 0 min
#   [ 405/500]  β=0.450 γ=0.103 ρ=0.443  | peak=0.776  rewires=394  rew_inf_ratio=1.015  | ETA: 0 min
#   [ 406/500]  β=0.150 γ=0.182 ρ=0.435  | peak=0.325  rewires=805  rew_inf_ratio=1.477  | ETA: 0 min
#   [ 407/500]  β=0.476 γ=0.030 ρ=0.731  | peak=0.919  rewires=818  rew_inf_ratio=1.403  | ETA: 0 min
#   [ 408/500]  β=0.126 γ=0.053 ρ=0.601  | peak=0.403  rewires=1060  rew_inf_ratio=1.372  | ETA: 0 min
#   [ 409/500]  β=0.386 γ=0.188 ρ=0.229  | peak=0.606  rewires=189  rew_inf_ratio=0.578  | ETA: 0 min
#   [ 410/500]  β=0.297 γ=0.141 ρ=0.455  | peak=0.581  rewires=523  rew_inf_ratio=1.174  | ETA: 0 min
#   [ 411/500]  β=0.170 γ=0.030 ρ=0.338  | peak=0.869  rewires=564  rew_inf_ratio=0.699  | ETA: 0 min
#   [ 412/500]  β=0.194 γ=0.118 ρ=0.070  | peak=0.628  rewires=83  rew_inf_ratio=0.191  | ETA: 0 min
#   [ 413/500]  β=0.407 γ=0.046 ρ=0.185  | peak=0.896  rewires=161  rew_inf_ratio=0.398  | ETA: 0 min
#   [ 414/500]  β=0.059 γ=0.069 ρ=0.238  | peak=0.394  rewires=910  rew_inf_ratio=0.708  | ETA: 0 min
#   [ 415/500]  β=0.206 γ=0.146 ρ=0.148  | peak=0.564  rewires=178  rew_inf_ratio=0.436  | ETA: 0 min
#   [ 416/500]  β=0.103 γ=0.143 ρ=0.572  | peak=0.072  rewires=198  rew_inf_ratio=2.903  | ETA: 0 min
#   [ 417/500]  β=0.399 γ=0.020 ρ=0.492  | peak=0.928  rewires=514  rew_inf_ratio=1.060  | ETA: 0 min
#   [ 418/500]  β=0.121 γ=0.137 ρ=0.321  | peak=0.407  rewires=640  rew_inf_ratio=0.963  | ETA: 0 min
#   [ 419/500]  β=0.080 γ=0.139 ρ=0.227  | peak=0.212  rewires=520  rew_inf_ratio=1.000  | ETA: 0 min
#   [ 420/500]  β=0.420 γ=0.107 ρ=0.431  | peak=0.779  rewires=397  rew_inf_ratio=0.967  | ETA: 0 min
#   [ 421/500]  β=0.251 γ=0.078 ρ=0.161  | peak=0.762  rewires=179  rew_inf_ratio=0.420  | ETA: 0 min
#   [ 422/500]  β=0.295 γ=0.099 ρ=0.723  | peak=0.653  rewires=1044  rew_inf_ratio=1.613  | ETA: 0 min
#   [ 423/500]  β=0.384 γ=0.040 ρ=0.800  | peak=0.852  rewires=1038  rew_inf_ratio=1.596  | ETA: 0 min
#   [ 424/500]  β=0.265 γ=0.149 ρ=0.330  | peak=0.553  rewires=396  rew_inf_ratio=0.895  | ETA: 0 min
#   [ 425/500]  β=0.465 γ=0.127 ρ=0.666  | peak=0.690  rewires=684  rew_inf_ratio=1.493  | ETA: 0 min
#   [ 426/500]  β=0.205 γ=0.121 ρ=0.526  | peak=0.528  rewires=888  rew_inf_ratio=1.299  | ETA: 0 min
#   [ 427/500]  β=0.385 γ=0.159 ρ=0.215  | peak=0.623  rewires=174  rew_inf_ratio=0.525  | ETA: 0 min
#   [ 428/500]  β=0.373 γ=0.075 ρ=0.775  | peak=0.776  rewires=998  rew_inf_ratio=1.582  | ETA: 0 min
#   [ 429/500]  β=0.348 γ=0.058 ρ=0.327  | peak=0.824  rewires=305  rew_inf_ratio=0.637  | ETA: 0 min
#   [ 430/500]  β=0.122 γ=0.137 ρ=0.295  | peak=0.385  rewires=615  rew_inf_ratio=0.909  | ETA: 0 min
#   [ 431/500]  β=0.317 γ=0.067 ρ=0.106  | peak=0.822  rewires=111  rew_inf_ratio=0.266  | ETA: 0 min
#   [ 432/500]  β=0.143 γ=0.091 ρ=0.678  | peak=0.095  rewires=360  rew_inf_ratio=3.474  | ETA: 0 min
#   [ 433/500]  β=0.131 γ=0.178 ρ=0.299  | peak=0.310  rewires=544  rew_inf_ratio=1.032  | ETA: 0 min
#   [ 434/500]  β=0.213 γ=0.162 ρ=0.191  | peak=0.532  rewires=237  rew_inf_ratio=0.564  | ETA: 0 min
#   [ 435/500]  β=0.382 γ=0.150 ρ=0.569  | peak=0.595  rewires=573  rew_inf_ratio=1.445  | ETA: 0 min
#   [ 436/500]  β=0.298 γ=0.146 ρ=0.326  | peak=0.578  rewires=347  rew_inf_ratio=0.844  | ETA: 0 min
#   [ 437/500]  β=0.311 γ=0.107 ρ=0.781  | peak=0.602  rewires=1160  rew_inf_ratio=1.578  | ETA: 0 min
#   [ 438/500]  β=0.214 γ=0.158 ρ=0.399  | peak=0.505  rewires=562  rew_inf_ratio=1.087  | ETA: 0 min
#   [ 439/500]  β=0.368 γ=0.063 ρ=0.402  | peak=0.849  rewires=413  rew_inf_ratio=0.901  | ETA: 0 min
#   [ 440/500]  β=0.196 γ=0.185 ρ=0.063  | peak=0.494  rewires=79  rew_inf_ratio=0.239  | ETA: 0 min
#   [ 441/500]  β=0.266 γ=0.041 ρ=0.423  | peak=0.881  rewires=535  rew_inf_ratio=0.942  | ETA: 0 min
#   [ 442/500]  β=0.289 γ=0.081 ρ=0.537  | peak=0.718  rewires=672  rew_inf_ratio=1.152  | ETA: 0 min
#   [ 443/500]  β=0.098 γ=0.028 ρ=0.275  | peak=0.823  rewires=749  rew_inf_ratio=0.621  | ETA: 0 min
#   [ 444/500]  β=0.401 γ=0.026 ρ=0.347  | peak=0.925  rewires=317  rew_inf_ratio=0.693  | ETA: 0 min
#   [ 445/500]  β=0.379 γ=0.054 ρ=0.149  | peak=0.847  rewires=129  rew_inf_ratio=0.333  | ETA: 0 min
#   [ 446/500]  β=0.064 γ=0.145 ρ=0.632  | peak=0.034  rewires=76  rew_inf_ratio=5.559  | ETA: 0 min
#   [ 447/500]  β=0.278 γ=0.138 ρ=0.477  | peak=0.583  rewires=556  rew_inf_ratio=1.156  | ETA: 0 min
#   [ 448/500]  β=0.309 γ=0.080 ρ=0.634  | peak=0.721  rewires=820  rew_inf_ratio=1.318  | ETA: 0 min
#   [ 449/500]  β=0.111 γ=0.057 ρ=0.179  | peak=0.683  rewires=389  rew_inf_ratio=0.460  | ETA: 0 min
#   [ 450/500]  β=0.094 γ=0.194 ρ=0.040  | peak=0.316  rewires=90  rew_inf_ratio=0.215  | ETA: 0 min
#   >> Saved 450 results to pilot_results.csv
#   [ 451/500]  β=0.206 γ=0.066 ρ=0.416  | peak=0.748  rewires=624  rew_inf_ratio=0.955  | ETA: 0 min
#   [ 452/500]  β=0.293 γ=0.131 ρ=0.121  | peak=0.656  rewires=116  rew_inf_ratio=0.308  | ETA: 0 min
#   [ 453/500]  β=0.154 γ=0.169 ρ=0.054  | peak=0.435  rewires=76  rew_inf_ratio=0.191  | ETA: 0 min
#   [ 454/500]  β=0.180 γ=0.158 ρ=0.713  | peak=0.066  rewires=194  rew_inf_ratio=4.348  | ETA: 0 min
#   [ 455/500]  β=0.098 γ=0.031 ρ=0.489  | peak=0.618  rewires=1272  rew_inf_ratio=0.960  | ETA: 0 min
#   [ 456/500]  β=0.426 γ=0.177 ρ=0.366  | peak=0.614  rewires=306  rew_inf_ratio=0.950  | ETA: 0 min
#   [ 457/500]  β=0.206 γ=0.067 ρ=0.673  | peak=0.691  rewires=1271  rew_inf_ratio=1.355  | ETA: 0 min
#   [ 458/500]  β=0.129 γ=0.105 ρ=0.089  | peak=0.581  rewires=172  rew_inf_ratio=0.274  | ETA: 0 min
#   [ 459/500]  β=0.220 γ=0.070 ρ=0.744  | peak=0.606  rewires=1423  rew_inf_ratio=1.485  | ETA: 0 min
#   [ 460/500]  β=0.190 γ=0.101 ρ=0.419  | peak=0.648  rewires=663  rew_inf_ratio=1.019  | ETA: 0 min
#   [ 461/500]  β=0.269 γ=0.197 ρ=0.418  | peak=0.446  rewires=486  rew_inf_ratio=1.175  | ETA: 0 min
#   [ 462/500]  β=0.391 γ=0.140 ρ=0.307  | peak=0.682  rewires=269  rew_inf_ratio=0.783  | ETA: 0 min
#   [ 463/500]  β=0.396 γ=0.124 ρ=0.797  | peak=0.591  rewires=1024  rew_inf_ratio=1.670  | ETA: 0 min
#   [ 464/500]  β=0.348 γ=0.110 ρ=0.791  | peak=0.608  rewires=1123  rew_inf_ratio=1.668  | ETA: 0 min
#   [ 465/500]  β=0.273 γ=0.168 ρ=0.196  | peak=0.563  rewires=194  rew_inf_ratio=0.510  | ETA: 0 min
#   [ 466/500]  β=0.123 γ=0.119 ρ=0.646  | peak=0.070  rewires=222  rew_inf_ratio=4.314  | ETA: 0 min
#   [ 467/500]  β=0.109 γ=0.168 ρ=0.523  | peak=0.095  rewires=315  rew_inf_ratio=3.189  | ETA: 0 min
#   [ 468/500]  β=0.105 γ=0.105 ρ=0.571  | peak=0.061  rewires=138  rew_inf_ratio=4.000  | ETA: 0 min
#   [ 469/500]  β=0.240 γ=0.021 ρ=0.132  | peak=0.907  rewires=157  rew_inf_ratio=0.279  | ETA: 0 min
#   [ 470/500]  β=0.388 γ=0.107 ρ=0.620  | peak=0.709  rewires=660  rew_inf_ratio=1.423  | ETA: 0 min
#   [ 471/500]  β=0.131 γ=0.064 ρ=0.280  | peak=0.701  rewires=563  rew_inf_ratio=0.669  | ETA: 0 min
#   [ 472/500]  β=0.218 γ=0.089 ρ=0.648  | peak=0.666  rewires=1099  rew_inf_ratio=1.369  | ETA: 0 min
#   [ 473/500]  β=0.115 γ=0.132 ρ=0.081  | peak=0.486  rewires=152  rew_inf_ratio=0.255  | ETA: 0 min
#   [ 474/500]  β=0.177 γ=0.172 ρ=0.326  | peak=0.343  rewires=405  rew_inf_ratio=0.968  | ETA: 0 min
#   [ 475/500]  β=0.393 γ=0.045 ρ=0.371  | peak=0.879  rewires=349  rew_inf_ratio=0.772  | ETA: 0 min
#   [ 476/500]  β=0.095 γ=0.190 ρ=0.314  | peak=0.166  rewires=576  rew_inf_ratio=1.518  | ETA: 0 min
#   [ 477/500]  β=0.457 γ=0.175 ρ=0.768  | peak=0.536  rewires=777  rew_inf_ratio=1.828  | ETA: 0 min
#   [ 478/500]  β=0.498 γ=0.164 ρ=0.618  | peak=0.618  rewires=543  rew_inf_ratio=1.476  | ETA: 0 min
#   [ 479/500]  β=0.172 γ=0.102 ρ=0.363  | peak=0.607  rewires=611  rew_inf_ratio=0.873  | ETA: 0 min
#   [ 480/500]  β=0.060 γ=0.197 ρ=0.178  | peak=0.097  rewires=311  rew_inf_ratio=1.155  | ETA: 0 min
#   [ 481/500]  β=0.369 γ=0.050 ρ=0.117  | peak=0.860  rewires=105  rew_inf_ratio=0.252  | ETA: 0 min
#   [ 482/500]  β=0.325 γ=0.064 ρ=0.511  | peak=0.807  rewires=594  rew_inf_ratio=1.119  | ETA: 0 min
#   [ 483/500]  β=0.491 γ=0.171 ρ=0.617  | peak=0.571  rewires=541  rew_inf_ratio=1.529  | ETA: 0 min
#   [ 484/500]  β=0.328 γ=0.100 ρ=0.556  | peak=0.714  rewires=641  rew_inf_ratio=1.196  | ETA: 0 min
#   [ 485/500]  β=0.278 γ=0.116 ρ=0.081  | peak=0.711  rewires=79  rew_inf_ratio=0.214  | ETA: 0 min
#   [ 486/500]  β=0.420 γ=0.160 ρ=0.484  | peak=0.613  rewires=426  rew_inf_ratio=1.116  | ETA: 0 min
#   [ 487/500]  β=0.077 γ=0.139 ρ=0.550  | peak=0.043  rewires=106  rew_inf_ratio=3.512  | ETA: 0 min
#   [ 488/500]  β=0.308 γ=0.081 ρ=0.399  | peak=0.764  rewires=456  rew_inf_ratio=0.877  | ETA: 0 min
#   [ 489/500]  β=0.314 γ=0.188 ρ=0.493  | peak=0.505  rewires=553  rew_inf_ratio=1.412  | ETA: 0 min
#   [ 490/500]  β=0.499 γ=0.074 ρ=0.565  | peak=0.814  rewires=499  rew_inf_ratio=1.235  | ETA: 0 min
#   [ 491/500]  β=0.377 γ=0.030 ρ=0.071  | peak=0.916  rewires=60  rew_inf_ratio=0.157  | ETA: 0 min
#   [ 492/500]  β=0.170 γ=0.056 ρ=0.049  | peak=0.787  rewires=72  rew_inf_ratio=0.135  | ETA: 0 min
#   [ 493/500]  β=0.450 γ=0.074 ρ=0.155  | peak=0.794  rewires=115  rew_inf_ratio=0.339  | ETA: 0 min
#   [ 494/500]  β=0.074 γ=0.085 ρ=0.633  | peak=0.057  rewires=124  rew_inf_ratio=4.561  | ETA: 0 min
#   [ 495/500]  β=0.435 γ=0.091 ρ=0.323  | peak=0.787  rewires=272  rew_inf_ratio=0.734  | ETA: 0 min
#   [ 496/500]  β=0.061 γ=0.128 ρ=0.065  | peak=0.374  rewires=210  rew_inf_ratio=0.310  | ETA: 0 min
#   [ 497/500]  β=0.296 γ=0.026 ρ=0.181  | peak=0.904  rewires=188  rew_inf_ratio=0.410  | ETA: 0 min
#   [ 498/500]  β=0.371 γ=0.132 ρ=0.080  | peak=0.720  rewires=66  rew_inf_ratio=0.199  | ETA: 0 min
#   [ 499/500]  β=0.248 γ=0.021 ρ=0.039  | peak=0.927  rewires=41  rew_inf_ratio=0.091  | ETA: 0 min
#   [ 500/500]  β=0.407 γ=0.026 ρ=0.141  | peak=0.923  rewires=114  rew_inf_ratio=0.298  | ETA: 0 min
#   >> Saved 500 results to pilot_results.csv
#
# Pilot complete. Total time: 0.7 min

# %%
# ── Pilot analysis ───────────────────────────────────────────────

pilot = pd.read_csv(OUTPUT_FILE)
print(f"Loaded {len(pilot)} pilot simulations\n")

# Prior-predictive sigma = std of each statistic across all pilot simulations.
# These are the normalization constants used in the ABC distance function.
# We use prior-predictive std (not observed std) because ABC samples from
# the entire prior, not just near the true theta.
sigma = {k: pilot[f"s_{k}"].std() for k in STAT_NAMES}

print(f"{'Statistic':<18} {'sigma (prior std)':>18} {'s_obs':>10} {'s_obs percentile':>18}")
print("-" * 68)
for k in STAT_NAMES:
    pct = stats.percentileofscore(pilot[f"s_{k}"].values, s_obs[k])
    print(f"  {k:<16} {sigma[k]:>18.4f} {s_obs[k]:>10.4f} {pct:>16.1f}th")

# Compute distances with correct s_obs and sigma
pilot["distance"] = pilot.apply(
    lambda row: normalized_distance(
        {k: row[f"s_{k}"] for k in STAT_NAMES}, s_obs, sigma
    ), axis=1
)

d = pilot["distance"].values
print(f"\nDistance distribution (7 statistics, normalized Euclidean):")
print(f"  Min:    {d.min():.4f}")
print(f"  1st %:  {np.percentile(d, 1):.4f}")
print(f"  2nd %:  {np.percentile(d, 2):.4f}")
print(f"  5th %:  {np.percentile(d, 5):.4f}")
print(f"  10th %: {np.percentile(d,10):.4f}")
print(f"  Median: {np.median(d):.4f}")

print(f"\nCandidate epsilon values:")
for q in [1, 2, 5, 10]:
    eps = np.percentile(d, q)
    n   = (d <= eps).sum()
    print(f"  epsilon = {eps:.4f}  (top {q}% = {n} pilot samples accepted)")

pilot.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved updated pilot (with distances) to {OUTPUT_FILE}")
# Out:
# Loaded 500 pilot simulations
#
# Statistic           sigma (prior std)      s_obs   s_obs percentile
# --------------------------------------------------------------------
#   peak_height                  0.2334     0.6571             54.8th
#   auc                         10.2460    11.3990             68.2th
#   growth_rate                  0.1160     0.3752             89.4th
#   time_to_peak                 4.1049     8.7500             77.6th
#   total_rewires              320.8391   545.1500             63.0th
#   rew_inf_ratio                0.9951     0.7466             36.2th
#   var_degree                   2.7097    10.3410             46.6th
#
# Distance distribution (7 statistics, normalized Euclidean):
#   Min:    0.5259
#   1st %:  0.6406
#   2nd %:  0.7805
#   5th %:  1.0026
#   10th %: 1.2549
#   Median: 2.2044
#
# Candidate epsilon values:
#   epsilon = 0.6406  (top 1% = 5 pilot samples accepted)
#   epsilon = 0.7805  (top 2% = 10 pilot samples accepted)
#   epsilon = 1.0026  (top 5% = 25 pilot samples accepted)
#   epsilon = 1.2549  (top 10% = 50 pilot samples accepted)
#
# Saved updated pilot (with distances) to pilot_results.csv

# %% [markdown]
# ### Distance metric: normalized Euclidean
#
# Each of the 7 statistics is divided by its prior-predictive standard deviation σ (computed from the pilot) before computing the Euclidean distance. This ensures all statistics contribute equally regardless of scale. We investigated whether Mahalanobis distance — which additionally accounts for correlations between statistics — would improve results. This analysis appears in Section 3 after the main ABC results, since it requires the Euclidean posterior as a comparison baseline.

# %%
# ── Prior-predictive figure ─────────────────────────────────────
fig, axes = plt.subplots(2, 4, figsize=(15, 7))
axes_list = list(axes.flat)   # convert to list ONCE before any loops

for i, k in enumerate(STAT_NAMES):
    ax = axes_list[i]
    pct = stats.percentileofscore(pilot[f"s_{k}"].values, s_obs[k])
    ax.hist(pilot[f"s_{k}"], bins=30, color="#7F77DD", alpha=0.7,
            edgecolor="white", linewidth=0.4)
    ax.axvline(s_obs[k], color="#D85A30", linewidth=2,linestyle="--", label=f"s_obs\n({pct:.0f}th %ile)")
    ax.set_title(k, fontsize=9)
    ax.set_xlabel("Statistic value", fontsize=8)
    ax.set_ylabel("Count", fontsize=8)
    ax.legend(fontsize=7)

# Distance distribution in the 8th panel (index 7)
ax = axes_list[7]
ax.hist(d, bins=40, color="#0F6E56", alpha=0.7,
        edgecolor="white", linewidth=0.4)
for q, ls, lbl in [(1, "solid", "1st"), (5, "dashed", "5th"), (10, "dotted", "10th")]:
    eps = np.percentile(d, q)
    ax.axvline(eps, color="#D85A30", linewidth=1.5, linestyle=ls,
            label=f"ε ({lbl} %ile) = {eps:.3f}")
ax.set_title("Distance distribution", fontsize=9)
ax.set_xlabel("Normalized distance to s_obs", fontsize=8)
ax.set_ylabel("Count", fontsize=8)
ax.legend(fontsize=7)

plt.suptitle(
    "Prior-predictive distributions vs s_obs (orange dashed, with percentile)\n"
    "and prior-predictive distance distribution with candidate ε values",
    fontsize=10
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpreting the pilot results
#
# The percentile column shows where s_obs sits in the prior-predictive
# distribution — how unusual the observed value is relative to random prior draws.
#
# - **growth_rate (89th percentile):** The observed early growth rate is faster
#   than 89% of prior draws. This is the most informative statistic — it strongly
#   prefers high β and will do the most work in ABC.
# - **time_to_peak (78th) and auc (68th):** Moderately informative, s_obs in
#   the upper portion of the prior-predictive.
# - **peak_height (55th), total_rewires (63rd), var_degree (47th):**
#   s_obs sits in the bulk — these statistics are well-covered by the prior.
# - **rew_inf_ratio (36th):** s_obs sits near the center of the prior-predictive,
#   confirming the statistic is comparable between observed and simulated data.
#
# The epsilon candidates (1st, 5th, 10th percentile of pilot distances) represent
# the tradeoff between posterior quality and computational cost. We run a
# confirmation pass at ε = 1.0026 (5th percentile, ~10,000 draws) before
# committing to the full run at ε = 0.6406 (1st percentile, ~50,000 draws).

# %% [markdown]
# ## 3. Rejection ABC

# %%
import time, os

# ── Epsilon choices (from pilot analysis) ─────────────────────────────────
EPSILON_5PCT  = 1.0026   # confirmation run — fast
EPSILON_1PCT  = 0.6406   # final run — quality

# ── How many total draws to attempt ───────────────────────────────────────
N_ABC_CONFIRM = 10_000   # ~14 min,  ~500 accepted at 5%
N_ABC_FULL    = 50_000   # ~70 min,  ~500 accepted at 1%

# ── Toggle: set to False for confirmation, True for full run ───────────────
FULL_RUN = False   # <-- to change for the full run at 1%

EPSILON   = EPSILON_1PCT  if FULL_RUN else EPSILON_5PCT
N_ABC     = N_ABC_FULL    if FULL_RUN else N_ABC_CONFIRM
ABC_FILE  = "abc_results_full.csv" if FULL_RUN else "abc_results_confirm.csv"

print(f"Mode       : {'FULL (1% epsilon)' if FULL_RUN else 'CONFIRMATION (5% epsilon)'}")
print(f"Epsilon    : {EPSILON:.4f}")
print(f"Max draws  : {N_ABC:,}")
print(f"Output file: {ABC_FILE}\n")

# ── Resume logic ───────────────────────────────────────────────────────────
if os.path.exists(ABC_FILE):
    existing     = pd.read_csv(ABC_FILE)
    accepted     = existing.to_dict("records")
    n_done       = existing.attrs.get("n_draws_attempted", len(accepted) * 20)
    # n_draws_attempted is stored in CSV metadata if available;
    # fall back to a rough estimate if loading an old file
    print(f"Resuming: {len(accepted)} accepted samples already saved.")
else:
    accepted = []
    n_done   = 0
    print("Starting fresh ABC run.")

# ── RNG: advance state past pilot draws so we get fresh parameter draws ───
# The pilot used seed 42 for 500 draws. We use a separate seed here so
# ABC draws are independent of the pilot.
rng_abc = np.random.default_rng(123)

# ── Main ABC loop ─────────────────────────────────────────────────────────
SAVE_EVERY    = 100    # save accepted samples every 100 draws (not every 100 accepted)
LOG_EVERY     = 500    # print progress every 500 draws

n_accepted_session = 0
t_start = time.time()

for i in range(n_done, N_ABC):

    # 1. Draw from prior
    beta, gamma, rho = sample_prior(rng_abc)

    # 2. Simulate and compute summary statistics
    s_sim = simulate_summary(beta, gamma, rho, REPS_PER_DRAW, rng_abc)

    # 3. Compute normalized distance to observed data
    d = normalized_distance(s_sim, s_obs, sigma)

    # 4. Accept or reject
    if d <= EPSILON:
        row = {
            "beta":     beta,
            "gamma":    gamma,
            "rho":      rho,
            "distance": d,
        }
        # Also store the simulated summary stats for diagnostics later
        row.update({f"s_{k}": v for k, v in s_sim.items()})
        accepted.append(row)
        n_accepted_session += 1

    # 5. Progress reporting
    draws_done  = i + 1
    elapsed     = time.time() - t_start
    rate        = draws_done / elapsed          # draws per second
    eta_min     = (N_ABC - draws_done) / rate / 60 if rate > 0 else 0
    accept_rate = len(accepted) / draws_done * 100

    if draws_done % LOG_EVERY == 0 or draws_done == N_ABC:
        print(f"  [{draws_done:6,}/{N_ABC:,}]"
            f"  accepted: {len(accepted):4d}"
            f"  rate: {accept_rate:.2f}%"
            f"  ETA: {eta_min:.0f} min",
            flush=True)

    # 6. Save incrementally
    if draws_done % SAVE_EVERY == 0 or draws_done == N_ABC:
        df_save = pd.DataFrame(accepted)
        # Store total draws attempted as a column so resume logic works
        df_save["n_draws_attempted"] = draws_done
        df_save.to_csv(ABC_FILE, index=False)

print(f"\nDone. Total draws: {N_ABC:,}")
print(f"Total accepted:   {len(accepted)}")
print(f"Acceptance rate:  {len(accepted)/N_ABC*100:.2f}%")
print(f"Runtime:          {(time.time()-t_start)/60:.1f} min")
print(f"Saved to:         {ABC_FILE}")
# Out:
# Mode       : CONFIRMATION (5% epsilon)
# Epsilon    : 1.0026
# Max draws  : 10,000
# Output file: abc_results_confirm.csv
#
# Resuming: 496 accepted samples already saved.
#   [10,000/10,000]  accepted:  496  rate: 4.96%  ETA: 0 min
#
# Done. Total draws: 10,000
# Total accepted:   496
# Acceptance rate:  4.96%
# Runtime:          0.1 min
# Saved to:         abc_results_confirm.csv

# %%
abc_5pct = pd.read_csv("abc_results_confirm.csv")
abc_1pct = pd.read_csv("abc_results_full.csv")

# Extract bookkeeping and clean up
for abc, label in [(abc_5pct, "5%"), (abc_1pct, "1%")]:
    if "n_draws_attempted" in abc.columns:
        abc.drop(columns=["n_draws_attempted"], inplace=True)

n_total_5pct = 10_000
n_total_1pct = 50_000

print(f"5% run:  {len(abc_5pct)} accepted / {n_total_5pct:,} draws  "
    f"(acceptance rate: {len(abc_5pct)/n_total_5pct*100:.2f}%)")
print(f"1% run:  {len(abc_1pct)} accepted / {n_total_1pct:,} draws  "
    f"(acceptance rate: {len(abc_1pct)/n_total_1pct*100:.2f}%)")

EPSILON_5PCT = 1.0026
EPSILON_1PCT = 0.6406
# Out:
# 5% run:  496 accepted / 10,000 draws  (acceptance rate: 4.96%)
# 1% run:  397 accepted / 50,000 draws  (acceptance rate: 0.79%)

# %%
# ── Mahalanobis distance investigation ────────────────────────────────────
#
# Motivation: our 7 summary statistics have residual correlations even after
# removing redundant pairs (highest cross-source r = 0.645 for time_to_peak
# vs total_rewires). Mahalanobis distance accounts for these by using the
# full prior-predictive covariance matrix Σ instead of just the diagonal.
#
# We check the condition number of Σ first — if ill-conditioned (> 1000),
# reliable matrix inversion is not possible and we fall back to Euclidean.

pilot = pd.read_csv("pilot_results.csv")

pilot_matrix = pilot[[f"s_{k}" for k in STAT_NAMES]].values
cov_matrix   = np.cov(pilot_matrix, rowvar=False)
cond_number  = np.linalg.cond(cov_matrix)

print("Prior-predictive covariance matrix:")
print(pd.DataFrame(cov_matrix, index=STAT_NAMES, columns=STAT_NAMES).round(4).to_string())
print(f"\nCondition number: {cond_number:.1f}")
print("(Threshold: < 1000 = stable, > 1000 = ill-conditioned)")

if cond_number < 1000:
    print("→ Well-conditioned. Proceeding with standard inverse.")
    cov_inv = np.linalg.inv(cov_matrix)
else:
    print("→ Ill-conditioned. Using pseudoinverse as fallback.")
    cov_inv = np.linalg.pinv(cov_matrix)

def mahalanobis_distance(s_sim, s_obs_dict, cov_inv):
    """
    Mahalanobis distance between simulated and observed summary vectors.
    Accounts for correlations between statistics via the full covariance matrix.
    Falls back to pseudoinverse when covariance matrix is ill-conditioned.
    """
    diff = np.array([s_sim[k] - s_obs_dict[k] for k in STAT_NAMES])
    return np.sqrt(diff @ cov_inv @ diff)

# Recompute pilot distances under Mahalanobis for epsilon selection
pilot["distance_mahal"] = pilot.apply(
    lambda row: mahalanobis_distance(
        {k: row[f"s_{k}"] for k in STAT_NAMES}, s_obs, cov_inv
    ), axis=1
)

d_mahal = pilot["distance_mahal"].values
EPSILON_MAHAL = np.percentile(d_mahal, 1)

print(f"\nPilot distances — Euclidean vs Mahalanobis:")
print(f"{'Percentile':<12} {'Euclidean':>12} {'Mahalanobis':>14}")
print("-" * 40)
for q in [1, 2, 5, 10, 50]:
    e = np.percentile(pilot["distance"].values, q)
    m = np.percentile(d_mahal, q)
    print(f"  {q}th %ile   {e:>12.4f} {m:>14.4f}")

print(f"\nEpsilon (Mahalanobis, 1st percentile): {EPSILON_MAHAL:.4f}")
# Out:
# Prior-predictive covariance matrix:
#                peak_height       auc  growth_rate  time_to_peak  total_rewires  rew_inf_ratio  var_degree
# peak_height         0.0545    1.6404       0.0186       -0.2705        -1.2017        -0.1466     -0.3425
# auc                 1.6404  104.9806       0.5077        2.4360       401.1755        -3.1157     -4.7998
# growth_rate         0.0186    0.5077       0.0135        0.0010         3.7254        -0.0798     -0.1412
# time_to_peak       -0.2705    2.4360       0.0010       16.8506       700.9719        -0.4333      4.8693
# total_rewires      -1.2017  401.1755       3.7254      700.9719    102937.7303        64.8778    602.1175
# rew_inf_ratio      -0.1466   -3.1157      -0.0798       -0.4333        64.8778         0.9901      1.6721
# var_degree         -0.3425   -4.7998      -0.1412        4.8693       602.1175         1.6721      7.3425
#
# Condition number: 23448808.9
# (Threshold: < 1000 = stable, > 1000 = ill-conditioned)
# → Ill-conditioned. Using pseudoinverse as fallback.
#
# Pilot distances — Euclidean vs Mahalanobis:
# Percentile      Euclidean    Mahalanobis
# ----------------------------------------
#   1th %ile         0.6406         0.8811
#   2th %ile         0.7805         0.9915
#   5th %ile         1.0026         1.1915
#   10th %ile         1.2549         1.4113
#   50th %ile         2.2044         2.5132
#
# Epsilon (Mahalanobis, 1st percentile): 0.8811

# %%
# ── Run ABC with Mahalanobis distance ─────────────────────────────────────

import time, os

MAHAL_FILE  = "abc_results_mahal.csv"
N_ABC_MAHAL = 50_000
rng_mahal   = np.random.default_rng(456)

if os.path.exists(MAHAL_FILE):
    existing_m = pd.read_csv(MAHAL_FILE)
    accepted_m = existing_m.drop(
        columns=["n_draws_attempted"], errors="ignore"
    ).to_dict("records")
    n_done_m = int(existing_m["n_draws_attempted"].iloc[-1]) \
            if "n_draws_attempted" in existing_m.columns else 0
    print(f"Resuming: {len(accepted_m)} accepted, {n_done_m} draws done")
else:
    accepted_m, n_done_m = [], 0
    print(f"Starting Mahalanobis ABC: {N_ABC_MAHAL:,} draws, ε = {EPSILON_MAHAL:.4f}")

t_start = time.time()

for i in range(n_done_m, N_ABC_MAHAL):
    beta, gamma, rho = sample_prior(rng_mahal)
    s_sim = simulate_summary(beta, gamma, rho, REPS_PER_DRAW, rng_mahal)
    d = mahalanobis_distance(s_sim, s_obs, cov_inv)

    if d <= EPSILON_MAHAL:
        row = {"beta": beta, "gamma": gamma, "rho": rho, "distance": d}
        row.update({f"s_{k}": s_sim[k] for k in STAT_NAMES})
        accepted_m.append(row)

    draws_done = i + 1
    elapsed = time.time() - t_start
    rate    = draws_done / elapsed
    eta_min = (N_ABC_MAHAL - draws_done) / rate / 60 if rate > 0 else 0

    if draws_done % 5000 == 0 or draws_done == N_ABC_MAHAL:
        print(f"  [{draws_done:6,}/{N_ABC_MAHAL:,}]"
            f"  accepted: {len(accepted_m):4d}"
            f"  rate: {len(accepted_m)/draws_done*100:.2f}%"
            f"  ETA: {eta_min:.0f} min", flush=True)

    if draws_done % 1000 == 0 or draws_done == N_ABC_MAHAL:
        df_m = pd.DataFrame(accepted_m)
        df_m["n_draws_attempted"] = draws_done
        df_m.to_csv(MAHAL_FILE, index=False)

print(f"\nDone. {len(accepted_m)} accepted / {N_ABC_MAHAL:,} draws "
    f"({len(accepted_m)/N_ABC_MAHAL*100:.2f}%)")
print(f"Runtime: {(time.time()-t_start)/60:.1f} min")
# Out:
# Resuming: 680 accepted, 50000 draws done
#
# Done. 680 accepted / 50,000 draws (1.36%)
# Runtime: 0.0 min

# %%
# ── Euclidean vs Mahalanobis posterior comparison ─────────────────────────

param_info = {
    "beta":  {"prior": (0.05, 0.50), "color": "#534AB7", "label": "β (infection rate)"},
    "gamma": {"prior": (0.02, 0.20), "color": "#0F6E56", "label": "γ (recovery rate)"},
    "rho":   {"prior": (0.00, 0.80), "color": "#D85A30", "label": "ρ (rewiring rate)"},
}

fig, axes = plt.subplots(2, 3, figsize=(13, 7), sharex="col")

abc_mahal = pd.read_csv(MAHAL_FILE)
if "n_draws_attempted" in abc_mahal.columns:
    abc_mahal = abc_mahal.drop(columns=["n_draws_attempted"])

print(f"Euclidean:   {len(abc_1pct)} accepted / {n_total_1pct:,} draws")
print(f"Mahalanobis: {len(abc_mahal)} accepted / {N_ABC_MAHAL:,} draws\n")

dist_runs = [
    (abc_1pct,  EPSILON_1PCT,  "Euclidean distance\n(ε = 0.6406)"),
    (abc_mahal, EPSILON_MAHAL, f"Mahalanobis distance\n(ε = {EPSILON_MAHAL:.4f})"),
]

for row_idx, (abc, eps, label) in enumerate(dist_runs):
    for col_idx, (param, info) in enumerate(param_info.items()):
        ax     = axes[row_idx, col_idx]
        vals   = abc[param].values
        lo, hi = info["prior"]

        ax.hist(vals, bins=30, density=True, color=info["color"],
                alpha=0.7, edgecolor="white", linewidth=0.4)
        ax.axhline(1.0 / (hi - lo), color="black", linewidth=1.2,
                linestyle="--", alpha=0.5, label="Prior")

        mean_val = vals.mean()
        ci_lo    = np.percentile(vals, 2.5)
        ci_hi    = np.percentile(vals, 97.5)
        ax.axvline(mean_val, color="black", linewidth=1.5,
                label=f"Mean = {mean_val:.3f}")
        ax.axvspan(ci_lo, ci_hi, alpha=0.12, color=info["color"],
                label=f"95% CI [{ci_lo:.3f}, {ci_hi:.3f}]")

        ax.set_xlim(lo, hi)
        ax.legend(fontsize=7)
        if row_idx == 1:
            ax.set_xlabel(info["label"], fontsize=10)
        if col_idx == 0:
            ax.set_ylabel(f"{label}\n\nDensity", fontsize=8)
        if row_idx == 0:
            ax.set_title(info["label"], fontsize=10)

plt.suptitle(
    "Euclidean vs Mahalanobis distance: marginal posteriors\n"
    "Similar means → Euclidean is not badly biased by residual correlations",
    fontsize=10
)
plt.tight_layout()
plt.show()

print("=" * 65)
print("EUCLIDEAN vs MAHALANOBIS — POSTERIOR COMPARISON")
print("=" * 65)
print(f"\n{'':20} {'── Euclidean ──':^22} {'── Mahalanobis ──':^22}")
print(f"{'Parameter':<12} {'Mean':>8} {'95% CI':>16}"
    f"  {'Mean':>8} {'95% CI':>16}")
print("-" * 65)

for param in ["beta", "gamma", "rho"]:
    ve  = abc_1pct[param].values
    vm  = abc_mahal[param].values
    cie = f"[{np.percentile(ve,2.5):.3f}, {np.percentile(ve,97.5):.3f}]"
    cim = f"[{np.percentile(vm,2.5):.3f}, {np.percentile(vm,97.5):.3f}]"
    print(f"  {param:<10} {ve.mean():>8.3f} {cie:>16}"
        f"  {vm.mean():>8.3f} {cim:>16}")

print("\nCI width comparison (positive = Mahalanobis wider):")
for param in ["beta", "gamma", "rho"]:
    ve = abc_1pct[param].values
    vm = abc_mahal[param].values
    we = np.percentile(ve, 97.5) - np.percentile(ve, 2.5)
    wm = np.percentile(vm, 97.5) - np.percentile(vm, 2.5)
    diff = (wm - we) / we * 100
    direction = "narrower" if diff < 0 else "wider"
    print(f"  {param}: Euclidean={we:.3f}  Mahalanobis={wm:.3f}"
        f"  ({abs(diff):.1f}% {direction})")
# Out:
# Euclidean:   397 accepted / 50,000 draws
# Mahalanobis: 680 accepted / 50,000 draws
# =================================================================
# EUCLIDEAN vs MAHALANOBIS — POSTERIOR COMPARISON
# =================================================================
#
#                         ── Euclidean ──       ── Mahalanobis ──
# Parameter        Mean           95% CI      Mean           95% CI
# -----------------------------------------------------------------
#   beta          0.174   [0.121, 0.241]     0.193   [0.124, 0.265]
#   gamma         0.087   [0.063, 0.116]     0.092   [0.058, 0.127]
#   rho           0.321   [0.215, 0.420]     0.333   [0.215, 0.450]
#
# CI width comparison (positive = Mahalanobis wider):
#   beta: Euclidean=0.121  Mahalanobis=0.141  (17.1% wider)
#   gamma: Euclidean=0.053  Mahalanobis=0.070  (32.5% wider)
#   rho: Euclidean=0.206  Mahalanobis=0.235  (14.5% wider)

# %% [markdown]
# ### Mahalanobis distance — interpretation
#
# The prior-predictive covariance matrix has a condition number of 23,448,809 — far exceeding the stability threshold of 1,000. The cause is the extreme scale difference between statistics: `total_rewires` has variance ~102,937 while `peak_height` has variance ~0.055, a difference of six orders of magnitude. Direct matrix inversion is numerically unreliable, so we fall back to the pseudoinverse.
#
# The Mahalanobis posteriors are uniformly wider than the Euclidean posteriors (β: 17% wider, γ: 33% wider, ρ: 15% wider) with slightly inflated means. This is consistent with an unreliable distance metric accepting parameter draws too far from s_obs. The pseudoinverse modifies the geometry of the distance function in ways that are not theoretically justified.
#
# Importantly, the posterior **means** under both distance functions agree closely (β: 0.174 vs 0.193, γ: 0.087 vs 0.092, ρ: 0.321 vs 0.333), which confirms that the normalized Euclidean distance is not badly biased by the residual correlations between statistics. The ill-conditioning is therefore an argument for retaining Euclidean distance, not for pre-standardising and retrying — the scale problem arises precisely because `total_rewires` operates on a fundamentally different scale than the other statistics, and this scale difference is already handled by the per-statistic normalisation in Euclidean distance.

# %%
# ── Side-by-side marginal posteriors ────────────────────────────
# Top row: 5% epsilon run. Bottom row: 1% epsilon run.

param_info = {
    "beta":  {"prior": (0.05, 0.50), "color": "#534AB7", "label": "β (infection rate)"},
    "gamma": {"prior": (0.02, 0.20), "color": "#0F6E56", "label": "γ (recovery rate)"},
    "rho":   {"prior": (0.00, 0.80), "color": "#D85A30", "label": "ρ (rewiring rate)"},
}

fig, axes = plt.subplots(2, 3, figsize=(13, 7), sharex="col")

run_info = [
    (abc_5pct, EPSILON_5PCT, n_total_5pct, "Confirmation run"),
    (abc_1pct, EPSILON_1PCT, n_total_1pct, "Full run"),
]

for row_idx, (abc, eps, n_total, run_label) in enumerate(run_info):
    for col_idx, (param, info) in enumerate(param_info.items()):
        ax = axes[row_idx, col_idx]
        vals = abc[param].values
        lo, hi = info["prior"]

        ax.hist(vals, bins=30, density=True, color=info["color"],
                alpha=0.7, edgecolor="white", linewidth=0.4, label="Posterior")

        prior_height = 1.0 / (hi - lo)
        ax.axhline(prior_height, color="black", linewidth=1.2,
                linestyle="--", alpha=0.5, label="Prior (uniform)")

        mean_val = vals.mean()
        ci_lo    = np.percentile(vals, 2.5)
        ci_hi    = np.percentile(vals, 97.5)
        ax.axvline(mean_val, color="black", linewidth=1.5,
                label=f"Mean = {mean_val:.3f}")
        ax.axvspan(ci_lo, ci_hi, alpha=0.12, color=info["color"],
                label=f"95% CI [{ci_lo:.3f}, {ci_hi:.3f}]")

        ax.set_xlim(lo, hi)
        ax.set_ylabel("Density", fontsize=9)
        ax.legend(fontsize=7)

        # Only label x-axis on bottom row
        if row_idx == 1:
            ax.set_xlabel(info["label"], fontsize=10)

        # Row label on leftmost column
        if col_idx == 0:
            ax.set_ylabel(f"{run_label}\n(ε={eps:.4f}, n={len(abc)})\n\nDensity",
                        fontsize=8)

plt.suptitle(
    "Rejection ABC marginal posteriors: confirmation run (top) vs full run (bottom)\n"
    "Tighter ε produces narrower, more accurate posteriors",
    fontsize=10
)
plt.tight_layout()
plt.show()

# %%
# ── Side-by-side pairwise scatter + summary comparison table ────

fig, axes = plt.subplots(2, 3, figsize=(14, 8))

pairs = [("beta", "gamma"), ("beta", "rho"), ("gamma", "rho")]

for row_idx, (abc, eps, n_total, run_label) in enumerate(run_info):
    for col_idx, (px, py) in enumerate(pairs):
        ax = axes[row_idx, col_idx]

        sc = ax.scatter(
            abc[px], abc[py],
            c=abc["distance"], cmap="viridis_r",
            s=14, alpha=0.6, linewidths=0
        )
        plt.colorbar(sc, ax=ax, label="Distance")

        lox, hix = param_info[px]["prior"]
        loy, hiy = param_info[py]["prior"]
        rect = plt.Rectangle((lox, loy), hix - lox, hiy - loy,
                            fill=False, edgecolor="gray",
                            linewidth=1, linestyle="--", alpha=0.5)
        ax.add_patch(rect)

        ax.set_xlim(lox - 0.02, hix + 0.02)
        ax.set_ylim(loy - 0.02, hiy + 0.02)
        ax.set_xlabel(param_info[px]["label"], fontsize=9)
        ax.set_ylabel(param_info[py]["label"], fontsize=9)

        if col_idx == 0:
            ax.set_ylabel(
                f"{run_label} (ε={eps:.4f})\n\n{param_info[py]['label']}",
                fontsize=8
            )

plt.suptitle(
    "Pairwise posterior scatter: confirmation run (top) vs full run (bottom)\n"
    "Darker = closer to s_obs.  Note β–ρ diagonal band: partial identifiability",
    fontsize=10
)
plt.tight_layout()
plt.show()

# ── Comparison summary table ───────────────────────────────────────────────
print("=" * 70)
print("POSTERIOR COMPARISON: 5% epsilon (confirmation) vs 1% epsilon (full)")
print("=" * 70)
print(f"\n{'':22} {'── 5% run ──':^28} {'── 1% run ──':^28}")
print(f"{'Parameter':<12} {'Mean':>8} {'Median':>8} {'95% CI':>16}"
    f"  {'Mean':>8} {'Median':>8} {'95% CI':>16}")
print("-" * 70)

for param in ["beta", "gamma", "rho"]:
    v5 = abc_5pct[param].values
    v1 = abc_1pct[param].values
    ci5 = f"[{np.percentile(v5,2.5):.3f}, {np.percentile(v5,97.5):.3f}]"
    ci1 = f"[{np.percentile(v1,2.5):.3f}, {np.percentile(v1,97.5):.3f}]"
    print(f"  {param:<10} {v5.mean():>8.3f} {np.median(v5):>8.3f} {ci5:>16}"
        f"  {v1.mean():>8.3f} {np.median(v1):>8.3f} {ci1:>16}")

print(f"\n  Accepted      {len(abc_5pct):>8,}                            "
    f"{len(abc_1pct):>8,}")
print(f"  Total draws   {n_total_5pct:>8,}                            "
    f"{n_total_1pct:>8,}")
print(f"  Accept rate   {len(abc_5pct)/n_total_5pct*100:>7.2f}%"
    f"                           {len(abc_1pct)/n_total_1pct*100:>7.2f}%")
print(f"\nCI width reduction (5% → 1%):")
for param in ["beta", "gamma", "rho"]:
    v5 = abc_5pct[param].values
    v1 = abc_1pct[param].values
    w5 = np.percentile(v5, 97.5) - np.percentile(v5, 2.5)
    w1 = np.percentile(v1, 97.5) - np.percentile(v1, 2.5)
    print(f"  {param}: {w5:.3f} → {w1:.3f}  ({(1 - w1/w5)*100:.0f}% narrower)")
# Out:
# ======================================================================
# POSTERIOR COMPARISON: 5% epsilon (confirmation) vs 1% epsilon (full)
# ======================================================================
#
#                                ── 5% run ──                 ── 1% run ──
# Parameter        Mean   Median           95% CI      Mean   Median           95% CI
# ----------------------------------------------------------------------
#   beta          0.206    0.206   [0.112, 0.305]     0.174    0.171   [0.121, 0.241]
#   gamma         0.094    0.092   [0.057, 0.143]     0.087    0.087   [0.063, 0.116]
#   rho           0.348    0.350   [0.194, 0.500]     0.321    0.322   [0.215, 0.420]
#
#   Accepted           496                                 397
#   Total draws     10,000                              50,000
#   Accept rate      4.96%                              0.79%
#
# CI width reduction (5% → 1%):
#   beta: 0.193 → 0.121  (37% narrower)
#   gamma: 0.086 → 0.053  (39% narrower)
#   rho: 0.307 → 0.206  (33% narrower)

# %%
# ── Pairwise scatter: FULL RUN ONLY (1% epsilon) ───────────────────────────

fig, axes = plt.subplots(1, 3, figsize=(14, 4))

pairs = [("beta", "gamma"), ("beta", "rho"), ("gamma", "rho")]

for col_idx, (px, py) in enumerate(pairs):
    ax = axes[col_idx]

    sc = ax.scatter(
        abc_1pct[px], abc_1pct[py],
        c=abc_1pct["distance"], cmap="viridis_r",
        s=14, alpha=0.6, linewidths=0
    )

    plt.colorbar(sc, ax=ax, label="Distance")

    # prior bounds box (same as before)
    lox, hix = param_info[px]["prior"]
    loy, hiy = param_info[py]["prior"]
    rect = plt.Rectangle(
        (lox, loy), hix - lox, hiy - loy,
        fill=False, edgecolor="gray",
        linewidth=1, linestyle="--", alpha=0.5
    )
    ax.add_patch(rect)

    # limits
    ax.set_xlim(lox - 0.02, hix + 0.02)
    ax.set_ylim(loy - 0.02, hiy + 0.02)

    # labels
    ax.set_xlabel(param_info[px]["label"], fontsize=9)
    ax.set_ylabel(param_info[py]["label"], fontsize=9)

# title (same tone as before)
plt.suptitle(
    "Pairwise posterior scatter: full run (1% epsilon)\n"
    "Darker = closer to s_obs.  Note β–ρ diagonal band: partial identifiability",
    fontsize=10
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparing confirmation and full runs
#
# Tightening ε from 1.0026 (5th percentile) to 0.6406 (1st percentile)
# produces substantially narrower posteriors across all three parameters:
#
# - β CI narrows by ~37% (0.191 → 0.121)
# - γ CI narrows by ~39% (0.087 → 0.053)
# - ρ CI narrows by ~34% (0.310 → 0.206)
#
# The posterior means shift slightly downward (β: 0.206 → 0.174, ρ: 0.347 → 0.321),
# indicating that the looser tolerance was accepting parameter draws producing
# epidemics somewhat larger and faster than the observed data. The tighter
# tolerance gives a more precise and accurate posterior.
#
# The β-ρ diagonal band visible in the pairwise scatter plots is present in both
# runs, confirming this is a genuine feature of the posterior rather than an
# artefact of the tolerance choice. We address this identifiability problem
# formally in Section 4.
#
# All subsequent analysis uses the full run results (ε = 0.6406, 397 accepted samples).

# %% [markdown]
# ## 4. Summary Statistics Analysis

# %%
# ── Summary statistics analysis — restricted ABC runs ────────────
#
# We run ABC three times with different summary statistic subsets to show
# how the choice of summaries affects the posterior, particularly the
# β-ρ identifiability problem.
#
# Set A: infection only      {peak_height, auc, growth_rate, time_to_peak}
# Set B: infection + rewiring {+ total_rewires, rew_inf_ratio}
# Set C: all seven            {+ var_degree}  <- existing full run
#
# We use epsilon at the 5th percentile of each set's own prior-predictive
# distance distribution (computed from the pilot), and target ~10,000 draws
# per set. The comparison is qualitative so confirmation-run settings suffice.
#
# Note: sigma (normalization constants) must be recomputed per set using
# only the statistics in that set. Using the full-vector sigma for a subset
# would give wrong relative weights.


# ── Recompute per-set sigma from pilot ────────────────────────────────────
# The pilot CSV contains prior-predictive simulated values for all 7 stats.
pilot = pd.read_csv("pilot_results.csv")

STAT_SETS = {
    "A_infection_only": [
        "peak_height", "auc", "growth_rate", "time_to_peak"
    ],
    "B_infection_rewiring": [
        "peak_height", "auc", "growth_rate", "time_to_peak",
        "total_rewires", "rew_inf_ratio"
    ],
    "C_all_seven": [
        "peak_height", "auc", "growth_rate", "time_to_peak",
        "total_rewires", "rew_inf_ratio", "var_degree"
    ],
}

# For each set, compute sigma and epsilon from the pilot distances
set_configs = {}

print("Per-set epsilon (5th percentile of pilot distances):")
print(f"{'Set':<25} {'n stats':>8} {'epsilon':>10}")
print("-" * 45)

for set_name, stat_list in STAT_SETS.items():
    # Sigma: prior-predictive std for this subset only
    sigma_set = {k: pilot[f"s_{k}"].std() for k in stat_list}

    # Recompute pilot distances using only this subset
    def _dist_set(row, slist, sig, sobs):
        return np.sqrt(sum(
            ((row[f"s_{k}"] - sobs[k]) / sig[k]) ** 2
            for k in slist if sig[k] > 0
        ))

    pilot_dists = pilot.apply(
        lambda row: _dist_set(row, stat_list, sigma_set, s_obs), axis=1
    )
    eps = np.percentile(pilot_dists, 5)

    set_configs[set_name] = {
        "stats":  stat_list,
        "sigma":  sigma_set,
        "epsilon": eps,
    }
    print(f"  {set_name:<23} {len(stat_list):>8} {eps:>10.4f}")
# Out:
# Per-set epsilon (5th percentile of pilot distances):
# Set                        n stats    epsilon
# ---------------------------------------------
#   A_infection_only               4     0.6089
#   B_infection_rewiring           6     0.9091
#   C_all_seven                    7     1.0026

# %%
# ── Run ABC for each statistic set ───────────────────────────────
# Runs three separate ABC passes (Sets A, B, C) and saves each to its own CSV.
# Set C uses the same epsilon and settings as Sets A and B for a fair comparison
#
# Runtime: ~14 min per set, ~42 min total.
# Each set saves incrementally so you can resume if interrupted.

N_ABC_SETS  = 10_000   # draws per set
REPS_PER_DRAW_SETS = 5  # keep consistent with main ABC run
rng_sets = np.random.default_rng(999)  # separate seed from main runs

for set_name, cfg in set_configs.items():
    output_file = f"abc_{set_name}.csv"

    # Resume logic
    if os.path.exists(output_file):
        existing = pd.read_csv(output_file)
        if "n_draws_attempted" in existing.columns:
            n_done = int(existing["n_draws_attempted"].iloc[-1])
        else:
            n_done = 0
        accepted = existing.drop(
            columns=["n_draws_attempted"], errors="ignore"
        ).to_dict("records")
        print(f"\n{set_name}: resuming from draw {n_done}, "
            f"{len(accepted)} accepted so far")
    else:
        accepted = []
        n_done   = 0
        print(f"\n{set_name}: starting fresh")

    print(f"  Stats : {cfg['stats']}")
    print(f"  Epsilon: {cfg['epsilon']:.4f}")

    t_start = time.time()

    for i in range(n_done, N_ABC_SETS):
        beta, gamma, rho = sample_prior(rng_sets)
        s_sim = simulate_summary(beta, gamma, rho, REPS_PER_DRAW_SETS, rng_sets)

        # Distance using only this set's statistics and sigma
        d = np.sqrt(sum(
            ((s_sim[k] - s_obs[k]) / cfg["sigma"][k]) ** 2
            for k in cfg["stats"] if cfg["sigma"][k] > 0
        ))

        if d <= cfg["epsilon"]:
            row = {"beta": beta, "gamma": gamma, "rho": rho, "distance": d}
            row.update({f"s_{k}": s_sim[k] for k in cfg["stats"]})
            accepted.append(row)

        draws_done = i + 1
        elapsed    = time.time() - t_start
        rate       = draws_done / elapsed
        eta_min    = (N_ABC_SETS - draws_done) / rate / 60 if rate > 0 else 0

        if draws_done % 1000 == 0 or draws_done == N_ABC_SETS:
            print(f"  [{draws_done:6,}/{N_ABC_SETS:,}]"
                f"  accepted: {len(accepted):4d}"
                f"  rate: {len(accepted)/draws_done*100:.2f}%"
                f"  ETA: {eta_min:.0f} min", flush=True)

        if draws_done % 500 == 0 or draws_done == N_ABC_SETS:
            df_save = pd.DataFrame(accepted)
            df_save["n_draws_attempted"] = draws_done
            df_save.to_csv(output_file, index=False)

    elapsed_total = time.time() - t_start
    print(f"  Done. {len(accepted)} accepted / {N_ABC_SETS:,} draws "
        f"({len(accepted)/N_ABC_SETS*100:.2f}%)  "
        f"in {elapsed_total/60:.1f} min")
# Out:
# A_infection_only: resuming from draw 10000, 350 accepted so far
#   Stats : ['peak_height', 'auc', 'growth_rate', 'time_to_peak']
#   Epsilon: 0.6089
#   Done. 350 accepted / 10,000 draws (3.50%)  in 0.0 min
#
# B_infection_rewiring: resuming from draw 10000, 371 accepted so far
#   Stats : ['peak_height', 'auc', 'growth_rate', 'time_to_peak', 'total_rewires', 'rew_inf_ratio']
#   Epsilon: 0.9091
#   Done. 371 accepted / 10,000 draws (3.71%)  in 0.0 min
#
# C_all_seven: resuming from draw 10000, 389 accepted so far
#   Stats : ['peak_height', 'auc', 'growth_rate', 'time_to_peak', 'total_rewires', 'rew_inf_ratio', 'var_degree']
#   Epsilon: 1.0026
#   Done. 389 accepted / 10,000 draws (3.89%)  in 0.0 min

# %%
# ── Load all three set results ───────────────────────────────────

abc_sets = {}
for set_name in STAT_SETS:
    df = pd.read_csv(f"abc_{set_name}.csv")
    if "n_draws_attempted" in df.columns:
        df = df.drop(columns=["n_draws_attempted"])
    abc_sets[set_name] = df

set_labels = {
    "A_infection_only":      "Set A: infection only\n(peak_height, auc, growth_rate, time_to_peak)",
    "B_infection_rewiring":  "Set B: infection + rewiring\n(+ total_rewires, rew_inf_ratio)",
    "C_all_seven":           "Set C: all 7 statistics\n(+ var_degree)",
}

print("Summary statistics analysis — accepted samples per set:")
print(f"{'Set':<25} {'Accepted':>10} {'Draws':>10} {'Rate':>8}")
print("-" * 55)
for set_name, df in abc_sets.items():
    print(f"  {set_name:<23} {len(df):>10,} "
        f"{N_ABC_SETS:>10,} {len(df)/N_ABC_SETS*100:>7.2f}%")
# Out:
# Summary statistics analysis — accepted samples per set:
# Set                         Accepted      Draws     Rate
# -------------------------------------------------------
#   A_infection_only               350     10,000    3.50%
#   B_infection_rewiring           371     10,000    3.71%
#   C_all_seven                    389     10,000    3.89%

# %%
# ── Figure — marginal posteriors across sets ─────────────────────
# Shows how each parameter's posterior changes as we add more statistics.
# β and ρ posteriors should narrow and shift as we move
# from Set A to Set C. γ should be relatively stable across sets since
# the infection timeseries already constrains it well.

fig, axes = plt.subplots(3, 3, figsize=(13, 10), sharex="col")

param_info = {
    "beta":  {"prior": (0.05, 0.50), "color": "#534AB7", "label": "β (infection rate)"},
    "gamma": {"prior": (0.02, 0.20), "color": "#0F6E56", "label": "γ (recovery rate)"},
    "rho":   {"prior": (0.00, 0.80), "color": "#D85A30", "label": "ρ (rewiring rate)"},
}

set_colors = {
    "A_infection_only":     "#9F9EAA",
    "B_infection_rewiring": "#534AB7",
    "C_all_seven":          "#0F6E56",
}

for row_idx, (set_name, df) in enumerate(abc_sets.items()):
    for col_idx, (param, info) in enumerate(param_info.items()):
        ax = axes[row_idx, col_idx]
        vals = df[param].values
        lo, hi = info["prior"]

        ax.hist(vals, bins=25, density=True,
                color=set_colors[set_name], alpha=0.75,
                edgecolor="white", linewidth=0.4)

        # Prior reference
        ax.axhline(1.0 / (hi - lo), color="black", linewidth=1,
                linestyle="--", alpha=0.4, label="Prior")

        mean_val = vals.mean()
        ci_lo    = np.percentile(vals, 2.5)
        ci_hi    = np.percentile(vals, 97.5)
        ax.axvline(mean_val, color="black", linewidth=1.5)
        ax.axvspan(ci_lo, ci_hi, alpha=0.15,
                color=set_colors[set_name])

        ax.set_xlim(lo, hi)

        # Annotations
        ax.text(0.97, 0.95,
                f"μ={mean_val:.3f}\n[{ci_lo:.3f}, {ci_hi:.3f}]",
                transform=ax.transAxes, ha="right", va="top",
                fontsize=7.5, color="black")

        if col_idx == 0:
            short = set_name.replace("_", " ").replace("A ", "A: ")\
                            .replace("B ", "B: ").replace("C ", "C: ")
            ax.set_ylabel(f"{short}\n\nDensity", fontsize=7.5)

        if row_idx == 2:
            ax.set_xlabel(info["label"], fontsize=10)

        if row_idx == 0:
            ax.set_title(info["label"], fontsize=10)

plt.suptitle(
    "Marginal posteriors across summary statistic sets\n"
    "Row A = infection only,  B = + rewiring,  C = + degree",
    fontsize=10
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Effect of summary statistic choice on marginal posteriors
#
# The most striking pattern is in the ρ column. Set A's ρ posterior (top-right)
# is nearly flat — almost indistinguishable from the uniform prior. The CI width
# of 0.668 spans 84% of the entire prior range [0.0, 0.8]. This is the
# identifiability problem stated quantitatively: **the infection time series
# alone carries almost no information about the rewiring rate**.
#
# Adding rewiring statistics in Set B produces an immediate and dramatic
# improvement — the ρ posterior becomes sharply peaked and the CI width falls
# to 0.318, a reduction of more than 50%. This confirms that total_rewires and
# rew_inf_ratio are the primary carriers of information about ρ.
#
# γ behaves differently: its posterior is already well-concentrated in Set A
# and remains stable across all three sets.
#
# β improves modestly from A to B but remains partially uncertain, which is
# consistent with the β-ρ degeneracy shown in the scatter plots below.

# %%
# ── Figure — β-ρ pairwise scatter across sets ───────────────────
# This is the central figure of the summary statistics analysis section.
# The β-ρ diagonal band should be widest in Set A (infection only) and
# progressively tighter in Sets B and C as rewiring and degree statistics
# break the degeneracy between high-β/high-ρ and low-β/low-ρ combinations.

fig, axes = plt.subplots(1, 3, figsize=(14, 4.5))

for ax, (set_name, df) in zip(axes, abc_sets.items()):
    sc = ax.scatter(
        df["beta"], df["rho"],
        c=df["distance"], cmap="viridis_r",
        s=14, alpha=0.65, linewidths=0
    )
    plt.colorbar(sc, ax=ax, label="Distance to s_obs")

    # Prior rectangle
    rect = plt.Rectangle((0.05, 0.0), 0.45, 0.80,
                        fill=False, edgecolor="gray",
                        linewidth=1, linestyle="--", alpha=0.4)
    ax.add_patch(rect)

    # Correlation in posterior
    r_val, _ = stats.pearsonr(df["beta"], df["rho"])
    ax.text(0.05, 0.97, f"r(β,ρ) = {r_val:+.3f}",
            transform=ax.transAxes, va="top", fontsize=9,
            color="black",
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white",
                    alpha=0.7, edgecolor="none"))

    ax.set_xlabel("β (infection rate)", fontsize=10)
    ax.set_ylabel("ρ (rewiring rate)", fontsize=10)
    ax.set_xlim(0.03, 0.52)
    ax.set_ylim(-0.02, 0.82)
    ax.set_title(set_labels[set_name], fontsize=9)

plt.suptitle(
    "β–ρ posterior scatter across summary statistic sets\n"
    "Diagonal band = partial identifiability.  "
    "Band narrows as more informative statistics are added.",
    fontsize=10
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The β-ρ identifiability problem
#
# β and ρ can both suppress the epidemic through different mechanisms — high β spreads infection
# fast, while high ρ causes susceptibles to rewire away before they can be infected.
# Different combinations of (high β, high ρ) and (low β, low ρ) can produce similar
# observed infection curves.
#
# The β-ρ scatter plots make this concrete. In Set A (infection only), r(β,ρ) = +0.867
# — a strong diagonal band spanning the full posterior. In Set B, adding rewiring
# statistics reduces this to r = +0.742, a meaningful improvement. Set C (r = +0.777)
# does not further reduce the correlation, which is expected: var_degree carries
# information orthogonal to the β-ρ relationship, as evidenced by its near-zero
# correlation with both peak_height (r = -0.134) and total_rewires in the observed data.
#
# The residual correlation of r ≈ +0.74 in Sets B and C represents an irreducible
# degeneracy given the available data sources and the ABC tolerance used. Resolving
# it further would require either a tighter ε, more replicates, or statistics that
# more directly measure the separate contributions of β and ρ to epidemic dynamics.

# %%
# ── Quantitative summary of the analysis ─────────────────────────
# Reports the key numbers you will cite in the report:
# posterior CI widths, β-ρ correlation, and posterior std per set.

print("=" * 68)
print("SUMMARY STATISTICS ANALYSIS — QUANTITATIVE RESULTS")
print("=" * 68)

print(f"\n{'':30} {'Set A':>10} {'Set B':>10} {'Set C':>10}")
print(f"{'':30} {'(inf only)':>10} {'(+rewire)':>10} {'(+degree)':>10}")
print("-" * 62)

for param in ["beta", "gamma", "rho"]:
    row_mean  = f"  {param} mean"
    row_width = f"  {param} 95% CI width"
    row_std   = f"  {param} posterior std"

    means  = [abc_sets[s][param].mean()  for s in STAT_SETS]
    widths = [np.percentile(abc_sets[s][param], 97.5) -
            np.percentile(abc_sets[s][param],  2.5) for s in STAT_SETS]
    stds   = [abc_sets[s][param].std() for s in STAT_SETS]

    print(f"{row_mean:<30} {means[0]:>10.4f} {means[1]:>10.4f} {means[2]:>10.4f}")
    print(f"{row_width:<30} {widths[0]:>10.4f} {widths[1]:>10.4f} {widths[2]:>10.4f}")
    print(f"{row_std:<30} {stds[0]:>10.4f} {stds[1]:>10.4f} {stds[2]:>10.4f}")
    print()

# β-ρ posterior correlation across sets
print(f"  {'β–ρ posterior correlation':<28}", end="")
for s in STAT_SETS:
    r, _ = stats.pearsonr(abc_sets[s]["beta"], abc_sets[s]["rho"])
    print(f" {r:>+10.3f}", end="")
print()
# Out:
# ====================================================================
# SUMMARY STATISTICS ANALYSIS — QUANTITATIVE RESULTS
# ====================================================================
#
#                                     Set A      Set B      Set C
#                                (inf only)  (+rewire)  (+degree)
# --------------------------------------------------------------
#   beta mean                        0.1914     0.2030     0.2046
#   beta 95% CI width                0.2183     0.1750     0.1833
#   beta posterior std               0.0567     0.0464     0.0512
#
#   gamma mean                       0.0887     0.0917     0.0942
#   gamma 95% CI width               0.0557     0.0752     0.0843
#   gamma posterior std              0.0155     0.0208     0.0235
#
#   rho mean                         0.3468     0.3648     0.3481
#   rho 95% CI width                 0.6681     0.3180     0.3155
#   rho posterior std                0.1911     0.0882     0.0868
#
#   β–ρ posterior correlation        +0.867     +0.742     +0.777

# %% [markdown]
# ### Summary
#
# The most important transition is A → B. Rewiring statistics are essential for
# identifying ρ — without them, ρ is essentially unidentified from the data.
# The degree histogram (Set C) provides independent structural information but
# does not further resolve the β-ρ degeneracy, consistent with our pre-ABC
# correlation analysis showing var_degree is orthogonal to the infection and
# rewiring signals.
#
# Our best estimates of the true parameters, from the full run (ε = 0.6406)
# using all seven statistics, are:
#
# | Parameter | Meaning | Posterior mean | 95% credible interval |
# |---|---|---|---|
# | β | Infection probability per S-I edge | 0.174 | [0.121, 0.241] |
# | γ | Recovery probability per infected agent | 0.087 | [0.063, 0.116] |
# | ρ | Rewiring probability per S-I edge | 0.321 | [0.215, 0.420] |

# %% [markdown]
# ## 4. Advanced Method: ABC-SMC
#
# We implement Sequential Monte Carlo ABC (Sisson, Fan & Tanaka 2007). Unlike rejection ABC which draws blindly from the prior, ABC-SMC runs a sequence of populations with decreasing tolerance thresholds ε₁ > ε₂ > ... > εₜ. Each population is initialised by resampling and perturbing the previous one using a Gaussian perturbation kernel, concentrating particles progressively closer to the observed data. This is more computationally efficient than rejection ABC for tight tolerances because proposals are made near previously accepted regions rather than drawn uniformly from the prior.
#
# The same 7-statistic summary vector and normalized Euclidean distance function from Sections 1–3 are used here, ensuring results are directly comparable with the rejection ABC posterior.

# %%
# ── ABC-SMC: estimate sigma from prior-predictive ─────────────────────────
# SMC uses its own sigma estimate (300 draws) rather than the pilot sigma.
# This is intentional — the SMC sigma is computed fresh here so the SMC
# section is self-contained and reproducible independently.

from scipy.stats import multivariate_normal

def estimate_sigma(n_draws, n_reps, rng):
    sims = []
    for _ in range(n_draws):
        beta, gamma, rho = sample_prior(rng)
        s_sim = simulate_summary(beta, gamma, rho, n_reps=n_reps, rng=rng)
        sims.append(s_sim)
    sims_df = pd.DataFrame(sims)
    sigma_smc = sims_df.std(axis=0, ddof=1).to_dict()
    return sigma_smc, sims_df

rng_smc_init = np.random.default_rng(42)
sigma_smc, prior_pred_df = estimate_sigma(
    n_draws=300, n_reps=REPS_PER_DRAW, rng=rng_smc_init
)
print("SMC sigma (prior-predictive std from 300 draws):")
for k, v in sigma_smc.items():
    print(f"  {k:<18}: {v:.5f}")
# Out:
# SMC sigma (prior-predictive std from 300 draws):
#   peak_height       : 0.23412
#   auc               : 10.04191
#   growth_rate       : 0.12205
#   time_to_peak      : 4.40161
#   total_rewires     : 316.34466
#   rew_inf_ratio     : 1.07972
#   var_degree        : 2.78306

# %%
# ── Prior support checker ─────────────────────────────────────────────────

def in_prior_support(theta):
    beta, gamma, rho = theta
    return (
        PRIOR["beta"][0]  <= beta  <= PRIOR["beta"][1] and
        PRIOR["gamma"][0] <= gamma <= PRIOR["gamma"][1] and
        PRIOR["rho"][0]   <= rho   <= PRIOR["rho"][1]
    )

# %%
# ── Weighted mean and covariance for SMC kernel ───────────────────────────

def weighted_mean_and_cov(particles, weights):
    particles = np.asarray(particles)
    weights   = np.asarray(weights)
    mean      = np.average(particles, axis=0, weights=weights)
    centered  = particles - mean
    cov       = np.einsum("i,ij,ik->jk", weights, centered, centered)
    return mean, cov

# %%
# ── ABC-SMC algorithm ─────────────────────────────────────────────────────

def abc_smc(n_particles, eps_schedule, n_reps, sigma, rng, max_tries_per_round=200000):
    populations   = []
    all_distances = []

    # Round 0: standard rejection ABC at eps_schedule[0]
    particles, distances = [], []
    n_tries = 0

    while len(particles) < n_particles:
        n_tries += 1
        theta = sample_prior(rng)
        s_sim = simulate_summary(*theta, n_reps=n_reps, rng=rng)
        d     = normalized_distance(s_sim, s_obs, sigma)

        if d <= eps_schedule[0]:
            particles.append(theta)
            distances.append(d)

        if n_tries >= max_tries_per_round and len(particles) < n_particles:
            raise RuntimeError(
                f"Round 0 could not fill {n_particles} particles. "
                f"Accepted {len(particles)} after {n_tries} tries. "
                f"eps={eps_schedule[0]:.4f}"
            )

    particles = np.array(particles)
    distances = np.array(distances)
    weights   = np.ones(n_particles) / n_particles
    ess       = 1.0 / np.sum(weights**2)
    acc_rate  = len(particles) / n_tries

    populations.append({
        "particles":   particles,
        "weights":     weights,
        "distances":   distances,
        "epsilon":     eps_schedule[0],
        "accept_rate": acc_rate,
        "ess":         ess,
        "n_tries":     n_tries
    })
    all_distances.append(distances)

    # Rounds 1+: resample and perturb
    for t in range(1, len(eps_schedule)):
        prev_particles = populations[-1]["particles"]
        prev_weights   = populations[-1]["weights"]

        _, weighted_cov = weighted_mean_and_cov(prev_particles, prev_weights)
        dim        = prev_particles.shape[1]
        kernel_cov = 1.0 * weighted_cov + 1e-6 * np.eye(dim)
        mvn        = multivariate_normal(mean=np.zeros(dim), cov=kernel_cov)

        new_particles, new_weights, new_distances = [], [], []
        n_tries = 0

        while len(new_particles) < n_particles:
            n_tries += 1

            if n_tries >= max_tries_per_round:
                raise RuntimeError(
                    f"Round {t} could not fill {n_particles} particles. "
                    f"Accepted {len(new_particles)} after {n_tries} tries. "
                    f"eps={eps_schedule[t]:.4f}"
                )

            idx      = rng.choice(len(prev_particles), p=prev_weights)
            ancestor = prev_particles[idx]
            theta    = ancestor + rng.multivariate_normal(
                mean=np.zeros(dim), cov=kernel_cov
            )

            if not in_prior_support(theta):
                continue

            s_sim = simulate_summary(*theta, n_reps=n_reps, rng=rng)
            d     = normalized_distance(s_sim, s_obs, sigma)

            if d > eps_schedule[t]:
                continue

            diffs       = theta - prev_particles
            kernel_vals = mvn.pdf(diffs)
            denom       = np.dot(prev_weights, kernel_vals)

            if (not np.isfinite(denom)) or (denom <= 1e-300):
                continue

            w = 1.0 / denom
            new_particles.append(theta)
            new_weights.append(w)
            new_distances.append(d)

        new_particles = np.array(new_particles)
        new_weights   = np.array(new_weights)
        new_distances = np.array(new_distances)

        wsum = np.sum(new_weights)
        if (not np.isfinite(wsum)) or (wsum <= 0):
            raise RuntimeError(f"Invalid weight sum in round {t}: {wsum}")

        new_weights = new_weights / wsum
        ess         = 1.0 / np.sum(new_weights**2)
        acc_rate    = len(new_particles) / n_tries

        populations.append({
            "particles":   new_particles,
            "weights":     new_weights,
            "distances":   new_distances,
            "epsilon":     eps_schedule[t],
            "accept_rate": acc_rate,
            "ess":         ess,
            "n_tries":     n_tries
        })
        all_distances.append(new_distances)

    return populations, all_distances

# %%
# ── Run ABC-SMC ───────────────────────────────────────────────────────────
# eps_schedule: sequence of decreasing tolerances.
# Round 0 uses eps=5.0 (very loose, easy to fill from prior).
# Final round uses eps=0.5 (tighter than our rejection ABC at 0.6406).
# n_particles=200 gives a manageable population size.

rng_smc = np.random.default_rng(42)

eps_schedule = [5.0, 3.5, 2.5, 1.8, 1.0, 0.5]

populations, all_distances = abc_smc(
    n_particles=500,
    eps_schedule=eps_schedule,
    n_reps=REPS_PER_DRAW,
    sigma=sigma_smc,
    rng=rng_smc
)

print(f"ABC-SMC complete. {len(populations)} populations.")
for t, pop in enumerate(populations):
    print(f"  Round {t}: eps={pop['epsilon']:.1f}  "
        f"acc_rate={pop['accept_rate']:.3f}  "
        f"ESS={pop['ess']:.1f}  "
        f"n_tries={pop['n_tries']:,}")
# Out:
# ABC-SMC complete. 6 populations.
#   Round 0: eps=5.0  acc_rate=0.935  ESS=500.0  n_tries=535
#   Round 1: eps=3.5  acc_rate=0.423  ESS=466.5  n_tries=1,181
#   Round 2: eps=2.5  acc_rate=0.401  ESS=469.6  n_tries=1,247
#   Round 3: eps=1.8  acc_rate=0.271  ESS=476.8  n_tries=1,844
#   Round 4: eps=1.0  acc_rate=0.096  ESS=483.3  n_tries=5,189
#   Round 5: eps=0.5  acc_rate=0.046  ESS=489.1  n_tries=10,878

# %% [markdown]
# ### ABC-SMC results

# %%
# ── Extract final SMC population ──────────────────────────────────────────

final_pop = populations[-1]
theta_smc = final_pop["particles"]   # shape (200, 3)
w_smc     = final_pop["weights"]
d_smc     = final_pop["distances"]

smc_df = pd.DataFrame(theta_smc, columns=["beta", "gamma", "rho"])
smc_df["weight"]   = w_smc
smc_df["distance"] = d_smc

print("SMC final population summary (weighted):")
for p in ["beta", "gamma", "rho"]:
    wmean = np.average(smc_df[p], weights=smc_df["weight"])
    print(f"  {p}: weighted mean = {wmean:.4f}")
smc_df.head()
# Out:
# SMC final population summary (weighted):
#   beta: weighted mean = 0.1674
#   gamma: weighted mean = 0.0854
#   rho: weighted mean = 0.3177
#        beta     gamma       rho    weight  distance
# 0  0.152503  0.084964  0.282227  0.001869  0.248718
# 1  0.149310  0.104392  0.290702  0.002220  0.308802
# 2  0.190284  0.100834  0.344624  0.001718  0.412050
# 3  0.160678  0.096993  0.280698  0.001842  0.385192
# 4  0.203416  0.081739  0.338511  0.001679  0.391096

# %%
# ── Load vanilla ABC results for comparison ───────────────────────────────

vanilla_abc = pd.read_csv("abc_results_full.csv")
vanilla_df  = vanilla_abc[["beta", "gamma", "rho", "distance"]].copy()
vanilla_df["weight"] = 1 / len(vanilla_df)
print(f"Vanilla ABC: {len(vanilla_df)} samples loaded")
# Out:
# Vanilla ABC: 397 samples loaded

# %%
# ── Distance distributions across SMC populations ────────────────────────

plt.figure(figsize=(7, 5))
for t, dist in enumerate(all_distances):
    plt.hist(dist, bins=25, alpha=0.4, density=True, label=f"SMC round {t} (ε={eps_schedule[t]})")
plt.xlabel("Distance to observed summaries")
plt.ylabel("Density")
plt.title("ABC-SMC: distance distributions across rounds")
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
# ── Final distance comparison: vanilla ABC vs SMC ─────────────────────────

plt.figure(figsize=(7, 5))
plt.hist(vanilla_df["distance"], bins=25, alpha=0.5, density=True, label="Vanilla ABC (ε=0.6406)")
plt.hist(smc_df["distance"],    bins=25, alpha=0.5, density=True, label=f"ABC-SMC final (ε={eps_schedule[-1]})")
plt.xlabel("Distance to s_obs")
plt.ylabel("Density")
plt.title("Final distance distributions: Vanilla ABC vs ABC-SMC")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ── Marginal posteriors: vanilla ABC vs ABC-SMC ───────────────────────────

params = ["beta", "gamma", "rho"]

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for i, p in enumerate(params):
    axes[i].hist(vanilla_df[p], bins=30, density=True, alpha=0.5, label="Vanilla ABC")
    axes[i].hist(smc_df[p], bins=30, weights=smc_df["weight"],
                density=True, alpha=0.5, label="ABC-SMC")
    axes[i].set_title(p)
    axes[i].legend()

plt.suptitle("Marginal posteriors: Vanilla ABC vs ABC-SMC", fontsize=11)
plt.tight_layout()
plt.show()

# %%
# ── Quantitative comparison: posterior means and 95% CIs ─────────────────

def weighted_quantile(values, quantiles, sample_weight=None):
    values = np.asarray(values)
    quantiles = np.asarray(quantiles)
    if sample_weight is None:
        sample_weight = np.ones(len(values))
    sample_weight = np.asarray(sample_weight)
    sorter = np.argsort(values)
    values = values[sorter]
    sample_weight = sample_weight[sorter]
    cdf = np.cumsum(sample_weight)
    cdf = cdf / cdf[-1]
    return np.interp(quantiles, cdf, values)

print(f"{'':10} {'Vanilla ABC':^30} {'ABC-SMC':^30}")
print(f"{'Param':<10} {'Mean':>8} {'2.5%':>8} {'97.5%':>8}   {'Mean':>8} {'2.5%':>8} {'97.5%':>8}")
print("-" * 68)

for p in params:
    v_mean = vanilla_df[p].mean()
    v_q    = vanilla_df[p].quantile([0.025, 0.975]).values
    s_mean = np.average(smc_df[p], weights=smc_df["weight"])
    s_q    = weighted_quantile(smc_df[p], [0.025, 0.975], sample_weight=smc_df["weight"])
    print(f"  {p:<8} {v_mean:>8.4f} {v_q[0]:>8.4f} {v_q[1]:>8.4f}"
        f"   {s_mean:>8.4f} {s_q[0]:>8.4f} {s_q[1]:>8.4f}")
# Out:
#                     Vanilla ABC                      ABC-SMC
# Param          Mean     2.5%    97.5%       Mean     2.5%    97.5%
# --------------------------------------------------------------------
#   beta       0.1737   0.1208   0.2414     0.1674   0.1227   0.2154
#   gamma      0.0875   0.0632   0.1159     0.0854   0.0652   0.1064
#   rho        0.3212   0.2148   0.4205     0.3177   0.2280   0.4037

# %%
# ── ESS Analysis on ABC-SMC across Populations  ─────────────────

ess_df = pd.DataFrame({
    "population": range(len(populations)),
    "epsilon": [pop["epsilon"] for pop in populations],
    "ESS": [pop["ess"] for pop in populations],
    "accept_rate": [pop["accept_rate"] for pop in populations],
    "n_tries": [pop["n_tries"] for pop in populations]
})

plt.figure(figsize=(6, 4))
plt.plot(ess_df["population"], ess_df["ESS"], marker="o")
plt.xticks(ess_df["population"])
plt.xlabel("SMC population")
plt.ylabel("Effective Sample Size (ESS)")
plt.title("ESS across ABC-SMC populations")
plt.grid(True, alpha=0.3)
plt.show()

# %%
# ── Pairwise posterior scatter: vanilla ABC vs ABC-SMC ────────────────────

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
pairs = [("beta", "gamma"), ("beta", "rho"), ("gamma", "rho")]

for ax, (x, y) in zip(axes, pairs):
    ax.scatter(vanilla_df[x], vanilla_df[y], alpha=0.35, s=15, label="Vanilla ABC")
    ax.scatter(smc_df[x], smc_df[y], alpha=0.35, s=15,
            c=smc_df["weight"], cmap="viridis", label="ABC-SMC")
    ax.set_xlabel(x)
    ax.set_ylabel(y)
    ax.set_title(f"{x} vs {y}")
    ax.legend(fontsize=8)

plt.suptitle("Pairwise scatter: Vanilla ABC vs ABC-SMC", fontsize=11)
plt.tight_layout()
plt.show()

print("Vanilla ABC — pairwise correlations:")
print(vanilla_df[params].corr().round(3))
print("\nABC-SMC — pairwise correlations (unweighted):")
print(smc_df[params].corr().round(3))
# Out:
# Vanilla ABC — pairwise correlations:
#         beta  gamma    rho
# beta   1.000  0.323  0.785
# gamma  0.323  1.000  0.181
# rho    0.785  0.181  1.000
#
# ABC-SMC — pairwise correlations (unweighted):
#         beta  gamma    rho
# beta   1.000  0.363  0.808
# gamma  0.363  1.000  0.250
# rho    0.808  0.250  1.000

# %%
# ── SMC population evolution across rounds ────────────────────────────────

fig, axes = plt.subplots(len(populations), 3, figsize=(12, 3 * len(populations)))

for t, pop in enumerate(populations):
    pop_df = pd.DataFrame(pop["particles"], columns=["beta", "gamma", "rho"])
    pop_w  = pop["weights"]
    for j, p in enumerate(params):
        axes[t, j].hist(pop_df[p], bins=25, weights=pop_w, density=True, alpha=0.7)
        axes[t, j].set_title(f"Round {t}  {p}  ε={pop['epsilon']}")

plt.suptitle("ABC-SMC: posterior evolution across rounds", fontsize=11)
plt.tight_layout()
plt.show()

# %%
# ── Posterior predictive check ────────────────────────────────────────────
# Simulate from posterior draws and compare to observed s_obs.
# If the method worked, posterior-predictive summaries should be centered
# on s_obs (orange dashed line).

def posterior_predictive_summaries(theta_samples, rng, n_reps):
    sims = []
    for theta in theta_samples:
        beta, gamma, rho = theta
        s_sim = simulate_summary(beta, gamma, rho, n_reps=n_reps, rng=rng)
        sims.append(s_sim)
    return pd.DataFrame(sims)

rng_ppc = np.random.default_rng(123)

theta_v_sub = vanilla_df[["beta", "gamma", "rho"]].sample(
    n=min(100, len(vanilla_df)), random_state=123
).values

pp_vanilla = posterior_predictive_summaries(theta_v_sub, rng_ppc, n_reps=REPS_PER_DRAW)

idx = rng_ppc.choice(len(smc_df), size=min(100, len(smc_df)),
                            replace=True, p=smc_df["weight"])
theta_s_sub = smc_df.loc[idx, ["beta", "gamma", "rho"]].values
pp_smc      = posterior_predictive_summaries(theta_s_sub, rng_ppc, n_reps=REPS_PER_DRAW)

summary_names = list(s_obs.keys())

fig, axes = plt.subplots(len(summary_names), 2, figsize=(10, 4 * len(summary_names)))

for i, sname in enumerate(summary_names):
    axes[i, 0].hist(pp_vanilla[sname], bins=25, alpha=0.7, color="#4C72B0")
    axes[i, 0].axvline(s_obs[sname], color="#D85A30", linestyle="--", linewidth=1.5)
    axes[i, 0].set_title(f"Vanilla ABC PPC: {sname}")

    axes[i, 1].hist(pp_smc[sname], bins=25, alpha=0.7, color="#CF7CAD")
    axes[i, 1].axvline(s_obs[sname], color="#D85A30", linestyle="--", linewidth=1.5)
    axes[i, 1].set_title(f"ABC-SMC PPC: {sname}")


plt.suptitle(
    "Posterior predictive check: red dashed = observed s_obs\n"
    "Well-calibrated posteriors should be centred on the dashed line",
    fontsize=14,
    y=0.98
)

plt.tight_layout(rect=[0, 0, 1, 0.96])
